# %% [markdown]
# #1. Load JSON files and normalize into a single DataFrame

# %%
files_to_process = ["/content/compoundV2_transactions_ethereum_chunk_0.json"
 ,"/content/compoundV2_transactions_ethereum_chunk_1.json"
 ,"/content/compoundV2_transactions_ethereum_chunk_32.json"]

# %%
import json
import pandas as pd
from datetime import datetime
import os
import glob # To find files if needed

# --- Configuration ---
# Assuming files are downloaded to a 'data' subfolder
# DATA_DIR = 'data/'
# Manually identify the 3 largest files or use os.getsize
# Example:
 # Replace with actual paths after downloading

# --- Data Loading Function ---
def load_data(filepath):
    """Loads transaction data from a single JSON file."""
    try:
        with open(filepath, 'r') as f:
            data = json.load(f)
        print(f"Loaded {filepath}")
        return data
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return None

# --- Data Processing Function ---
def process_raw_data(raw_data_list):
    """Processes raw data from multiple files into a single DataFrame."""
    all_tx = []
    tx_types = ['deposits', 'borrows', 'repayments', 'withdrawals', 'liquidations'] # Adjust based on actual keys

    for data in raw_data_list:
        if data is None:
            continue
        for tx_type, transactions in data.items():
            # Normalize key name if needed (e.g., 'repayments' vs 'repays')
            normalized_tx_type = tx_type.lower().replace('s', '') # Simple normalization
            if 'repayment' in normalized_tx_type: normalized_tx_type = 'repay'
            if 'withdrawal' in normalized_tx_type: normalized_tx_type = 'withdraw'

            if not isinstance(transactions, list):
                print(f"Warning: Expected list for {tx_type}, got {type(transactions)}. Skipping.")
                continue

            for tx in transactions:
                try:
                    record = {
                        'tx_hash': tx.get('hash'),
                        'log_id': tx.get('id'), # Unique identifier for the event log
                        'timestamp': pd.to_datetime(int(tx.get('timestamp')), unit='s'),
                        'tx_type': normalized_tx_type,
                        'wallet_id': tx.get('account', {}).get('id'),
                        'asset_symbol': tx.get('asset', {}).get('symbol'),
                        'asset_id': tx.get('asset', {}).get('id'),
                        'amount': float(tx.get('amount', 0)),
                        'amountUSD': float(tx.get('amountUSD', 0)),
                        'liquidator': None,
                        'liquidated_account': None
                    }

                    if normalized_tx_type == 'liquidation':
                        # Liquidation specific fields
                        record['liquidator'] = tx.get('liquidator', {}).get('id')
                        # The 'account' in a liquidation event is the one being liquidated
                        record['liquidated_account'] = tx.get('account', {}).get('id')
                        # For consistency, let's track activity for both liquidator and liquidated
                        # We'll create two effective records or handle during feature engineering
                        # For now, let's focus on the primary actor involved in the tx log:
                        # If we process by wallet, we need to know WHO initiated what.
                        # Let's keep the 'wallet_id' as the 'account' for now,
                        # and use the 'liquidator' field separately during aggregation.
                        # OR: Create separate entries for liquidator action?
                        # Simpler: Process liquidations separately in feature engineering.
                        # Let's assign the primary 'wallet_id' to the liquidated account here.
                        record['wallet_id'] = record['liquidated_account']


                    # Basic validation
                    if record['wallet_id'] and record['timestamp']:
                        all_tx.append(record)
                    else:
                         print(f"Skipping record due to missing wallet_id or timestamp: {tx.get('id')}")


                except Exception as e:
                    print(f"Error processing record {tx.get('id', 'N/A')} in {tx_type}: {e}")

    df = pd.DataFrame(all_tx)
    df = df.sort_values(by='timestamp').reset_index(drop=True)
    print(f"Processed {len(df)} total transactions.")
    return df

# --- Main Loading Sequence ---
raw_data_loaded = []
for f_path in files_to_process:
    raw_data_loaded.append(load_data(f_path))

# Filter out any None results from failed loads
raw_data_loaded = [d for d in raw_data_loaded if d is not None]

if not raw_data_loaded:
    print("Error: No data loaded. Exiting.")
    exit()

df_tx = process_raw_data(raw_data_loaded)

# --- Initial Data Cleaning ---
df_tx = df_tx.dropna(subset=['wallet_id', 'timestamp', 'amountUSD'])
df_tx = df_tx[df_tx['amountUSD'] >= 0] # Ensure no negative amounts make it through

print("Sample processed data:")
print(df_tx.head())
print("\nTransaction Types Found:")
print(df_tx['tx_type'].value_counts())
print(f"\nNumber of unique wallets: {df_tx['wallet_id'].nunique()}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping record due to missing wallet_id or timestamp: 0x0afbada6cb79ac19b7fe74ddb7fa1cc5ea807674740089d289862dc108212282-37
# Skipping record due to missing wallet_id or timestamp: 0x0eb51ad904a154523cd942ce1131394f29b7f08afa6237bda4ffb56c3c7fb365-10
# Skipping record due to missing wallet_id or timestamp: 0x5f01f0bc33e506b64c8f9ef26ee452740b44845df9141aab24cacf1d67de45db-50
# Skipping record due to missing wallet_id or timestamp: 0xcb11522aa279b93e49b0a129133f2ba74b6140c35eafd74a3732e2035aa4e127-452
# Skipping record due to missing wallet_id or timestamp: 0x39cbd2f486c8f5effab64004083f74af26ea4097ded45d34f33d7809d9dc56c4-29
# Skipping record due to missing wallet_id or timestamp: 0x014907dd3220cb1e3d9987f7987d9751fcf5cdbbc890346c21e9a4a103f1c5c0-10
# Skipping record due to missing wallet_id or timestamp: 0x79e2443aba3a3799c0e287c84e4ce41547b878088f7c9fc7f5a37e69dc959d50-53
# Skipping record due to missing wallet_id or timestamp: 0xe4c39e5a403fc5bd1d4c2dcc4cc65d8b77b0b42e1b7e7ee4e217c9e0cb79e455-10
# Skipping record due to missing wallet_id or timestamp: 0x173bc3039def830cadabdc908670ff436cf4c9e6515a3fc91a91a6929d5e3b70-10
# Skipping record due to missing wallet_id or timestamp: 0x7e4adf4e057c43522a52320a5eacaa3203c63c466721dbb870682d53d1d92fea-51
# Skipping record due to missing wallet_id or timestamp: 0x051bcb216d26cb996428adaa060ebc62f3341349d9555ea9214f6360fa1837fc-16
# Skipping record due to missing wallet_id or timestamp: 0x60cfecd61b7b544385950f39bd6dcab5e1c331abae13da5c649d648824da6fa4-185
# Skipping record due to missing wallet_id or timestamp: 0x1331e32d990a1221f0decd32efe5b946ad1e501f952fb207160391e3de1cf311-22
# Skipping record due to missing wallet_id or timestamp: 0x5f2e0066b9918c6ff8e12e6a14acaf86159f7b4f8905c090262e350bebcb75c6-14
# Skipping record due to missing wallet_id or timestamp: 0x438384eb6c4114e0758ce1749ac028e93f6b8bdb1a93de067c3a8a7785ceb1c9-10
# Skipping record due to missing wallet_id or timestamp: 0x3cf6f27272582a86a1439b21f8378abf98b35df255ee736fa1e94a719ec46914-10
# Skipping record due to missing wallet_id or timestamp: 0x585c396a3713856aab2e096e6fe76a073638b4227f5a1044a3dd1b201fa0662c-37
# Skipping record due to missing wallet_id or timestamp: 0xea2834a06d75349be1c524f71b41ce5ff16d39e1fdbd6eb85a6a1cfc6a14460a-20
# Skipping record due to missing wallet_id or timestamp: 0x1b3e2be613b0b3c482abdbaa35cae03d5d78eb4f72eca8362dddb694a298dd09-62
# Skipping record due to missing wallet_id or timestamp: 0xd4d2ba20b18e9040e59b0e6b05f1f3625dbca27c12687bdaaff86be5e05eeb11-10
# Skipping record due to missing wallet_id or timestamp: 0xaece30863c7f5204e4270bf0e51eef60dd90838eda75978416e1fe5c88481f38-25
# Skipping record due to missing wallet_id or timestamp: 0x0ebca961acb2600e587bc219ce47c2dea756bac4845840496fd3b8d5630a0e10-10
# Skipping record due to missing wallet_id or timestamp: 0xea2a8887fce0af72b3e54f56315c1a0bc9254f19d8726f1c9a667ef2a48a1c4c-23
# Skipping record due to missing wallet_id or timestamp: 0x8d1c8333fc91f3fea1f3d9e5deed75a5b1b4ac4c8a84e1cc663baa99916ee2e9-222
# Skipping record due to missing wallet_id or timestamp: 0xc4f6db0e59d65c9dcb47d3ec3aeaabec7eee949bfe62785b9236cc273799a989-87
# Skipping record due to missing wallet_id or timestamp: 0x81adb19a7cff18eaba04f69e6aad3b7846d6c325fb757f0eeabc37879ff78e2c-32
# Skipping record due to missing wallet_id or timestamp: 0xdb80f0e8816ae1986e7761d7889175df4715e5149b5c5a804f2b1333f45c9196-214
# Skipping record due to missing wallet_id or timestamp: 0x7d9868a123352849e380729bbccb2d99c419828eb1425306561a34e8592c892b-147
# Skipping record due to missing wallet_id or timestamp: 0x3c06a3e1c039b8efbddb61e38d1eb5c33b52cef3377d3207245c17bcc30632dc-10
# Skipping record due to missing wallet_id or timestamp: 0x6e58e95deb52049f9198efe8b3586a93398ee56d032048c8f599c4d941ad88d6-69
# Skipping record due to missing wallet_id or timestamp: 0x9f42c43f32e92b1d9115ac51c61445b16b15e9a4b7b139e23fbd9403d5bc532f-63
# Skipping record due to missing wallet_id or timestamp: 0x2dcb68c6fac5a5e3df23eaeb9a0e2847322699a68c46a696bf2af46283360d34-221
# Skipping record due to missing wallet_id or timestamp: 0xc464c38a082d5f4044198398b058da2a7a8c2b4a0130643a63dc9d6acf661f61-120
# Skipping record due to missing wallet_id or timestamp: 0xc532f4b665c8f205a1daf071bd9ba2aeeaf6a568705876473ae657d40e5d01aa-46
# Skipping record due to missing wallet_id or timestamp: 0x8a1e24c12028089cb10df500ccdb9cbd507e83ef3c9281042f0745f41b59b364-46
# Skipping record due to missing wallet_id or timestamp: 0x287670ea20a4a7f5a3309e5246d68fcd12084e0cff6a06bce30a79b938a220c8-13
# Skipping record due to missing wallet_id or timestamp: 0x7fe4e73826a65b733f13966df7212f2b0f2e37ab01d9802531d44a70e99784ce-61
# Skipping record due to missing wallet_id or timestamp: 0xabc1d824259d6a08556b116917550f861bec8670d4ade84da4759d89fda87910-55
# Skipping record due to missing wallet_id or timestamp: 0xef1c76c66af6e5e66e808cefc55260e35aba70439e9c42d5d2ab1990f76a60ba-25
# Skipping record due to missing wallet_id or timestamp: 0xc9be693dfeb4310adffc749817bfccab79d14de203b261ffcb6181a613db7cdb-33
# Skipping record due to missing wallet_id or timestamp: 0x5f1fa0b57a52d2581fc26729ad2b5c93d7c26ef1db4b28e0b531294c64f9f63f-61
# Skipping record due to missing wallet_id or timestamp: 0x83d9554970463d5de4139059e0b644f35c5a064a94b4147143923b3ef098743c-22
# Skipping record due to missing wallet_id or timestamp: 0xccdba40bf538baa54ea1b11a7f4c180c944ff0f95ff9b2ab484aaf30892ed610-67
# Skipping record due to missing wallet_id or timestamp: 0x0e50ef473ef16cc6f9d808a42b93b30877f21e3ed5561216323ed3a950715610-97
# Skipping record due to missing wallet_id or timestamp: 0xe382c8befae1e4e06752c5f093dc1bccc32a8e27fd9967423d732e19b0c88433-29
# Skipping record due to missing wallet_id or timestamp: 0x0730671576b8eb80ad1ce71f70bbc1a83505cfa7b42dd95ceb72b7b0bbf1f547-23
# Skipping record due to missing wallet_id or timestamp: 0x071e1726626049636b818b53a0aa9fe4aa29a23d415524c2e0567f708ff14ae4-41
# Skipping record due to missing wallet_id or timestamp: 0x5289b89d558f0172cced093ca926c535ce62ab14049d59cb9655ad0d754c78c9-55
# Skipping record due to missing wallet_id or timestamp: 0xcb47e9d2a1adde6dba4a918e3897c1c8abe59a6bfd1349ac69f6cc5cbddcd342-25
# Skipping record due to missing wallet_id or timestamp: 0x76fd3f5f0d2cdea02f34236e1d89077e5b75aa4e959928c7b94282eb9197dee6-118
# Skipping record due to missing wallet_id or timestamp: 0x1b69db79068b35fd9a5413937343b3c83b1653064942a5da6674a0fe0e4c6837-19
# Skipping record due to missing wallet_id or timestamp: 0xb7dfef97c23349d13abb79697d9f9dc656a5b91dd3931a92d75eafdc225c9605-54
# Skipping record due to missing wallet_id or timestamp: 0x139a6de0d8e3d155357b1396223643d4acc0306b498bff5ce756e23c5607c692-30
# Skipping record due to missing wallet_id or timestamp: 0x8d7633238834bad411a2d816116b0b1b068cdff6adcae5b4e2d7c27eba43a783-10
# Skipping record due to missing wallet_id or timestamp: 0x2e58c6f32160e87f68260565986c67c94d4bb32bf261531190037767b859fae4-10
# Skipping record due to missing wallet_id or timestamp: 0x07a3809d4e5e97a6bfcde4fe541a90e0c3a7e0c679a61172ffc30fa1267b75f7-10
# Skipping record due to missing wallet_id or timestamp: 0xe38968f6d5f447e15e7a11af84a41b9b5ce6ac21953b85848cdcb4a99f42988b-77
# Skipping record due to missing wallet_id or timestamp: 0xbf3d41ab75b7e4f54a168406dc32c27fd99a57133f2fc6b677457644a9f24f42-10
# Skipping record due to missing wallet_id or timestamp: 0x3d02cbc4b63d6eb5092af3c56aa179cfe083b6d3251c1a26fb5eb61574de963f-36
# Skipping record due to missing wallet_id or timestamp: 0x51c154ddd1eb2f5632fe80655f493119fe6aa9bb7fdb5ef8e21d6ea5eab99a5d-458
# Skipping record due to missing wallet_id or timestamp: 0x01f55e2314a7f4fc7f52ba87caab5932eb4bd05576950022160421975858f68b-371
# Skipping record due to missing wallet_id or timestamp: 0x7396e0c295b5f63ae98c8af91d3e46001e17c88beb91fb320210270d1a71352a-197
# Skipping record due to missing wallet_id or timestamp: 0x98baf1cccddfcb2c28741bcec183413de9fe0b242c0f3f1a3d64c6ad51198dd9-120
# Skipping record due to missing wallet_id or timestamp: 0xfc41fa08d05130dce814b5e60241727c02ca665f28bbd46cd36d8d62ff31640d-28
# Skipping record due to missing wallet_id or timestamp: 0xfcc68bdf43b4676a1759329a62eac460f239281c3ad96617d3a5f6662a20782c-170
# Skipping record due to missing wallet_id or timestamp: 0x00a21b1536fe7813a8984f4b024358de20fd987a78b2ff37204421a62ef92188-202
# Skipping record due to missing wallet_id or timestamp: 0x027d122524706088b23532ef61ec89865f5938b2aba279e6864b5bed05b3b635-182
# Skipping record due to missing wallet_id or timestamp: 0x0fd8f693fda248aa0748752dbd9a80860f9c68841758f22436f3f08f08054f17-193
# Skipping record due to missing wallet_id or timestamp: 0x238b90bfdf7e5d1147efcbf3bb7ae8a6316004f3ee2e67c68e60cc741ee43c04-48
# Skipping record due to missing wallet_id or timestamp: 0x59bd5c229d872b1cbe2868aea1c4db2269fa7ca8f2fabc109f8c215b2a92d177-59
# Skipping record due to missing wallet_id or timestamp: 0x643e07f9b1a400b859668dd608bd7f2966904988d5440ccaa2d73257603b24c2-163
# Skipping record due to missing wallet_id or timestamp: 0xaa922ff245326ead8b44418d1fdc3fc7d9effbccf4cbc6a19976cd2b4de4366e-554
# Skipping record due to missing wallet_id or timestamp: 0xab95a74b80deba58fd153a5358f6ce665d06a00216e144335018f7210abe13e4-173
# Skipping record due to missing wallet_id or timestamp: 0xd19ffefa25031dae28e4fbb173033c7761422758e709e4465f6cd5fadbf65c03-39
# Skipping record due to missing wallet_id or timestamp: 0xd4261207401f9db44b3de4e11730d86e83639a20d6dc9baa7d1c670815e2da92-69
# Skipping record due to missing wallet_id or timestamp: 0xe41adf874ab70124e3d7323b6c518fda246587280428cdf08dca5882d6e6d8f5-79
# Skipping record due to missing wallet_id or timestamp: 0x6284249173f81c2aa32cf69f6acf0cedf194ef0d0a693a9880521b58e5ca9a86-229
# Skipping record due to missing wallet_id or timestamp: 0x3434ecdf46a0ab4bf3cbd239cdcb27a8bec1bd70f4dfb7734ceebd42a3a9d0c1-256
# Skipping record due to missing wallet_id or timestamp: 0x8373bef7b99b22ef1b7028552bb2fcc17b6b7bf4032e1647d6f6f7e647b3eb3f-182
# Skipping record due to missing wallet_id or timestamp: 0xc6272916b87f923c831b19c31b5889e55efd3360a7825a39d736ee0329c137ed-225
# Skipping record due to missing wallet_id or timestamp: 0xf09d7cef712c37f34cee80b23e8153cb09b712a27a0b0660bee2bbdda34d9d55-300
# Skipping record due to missing wallet_id or timestamp: 0x3f3fa6784c0e80d9edc6f627376b337ef89599fae8f559cdf7eac5f1caf2fd38-177
# Skipping record due to missing wallet_id or timestamp: 0xa66e0622fd90119d7ef75ec61dec005e537857da6a9eaf24eb51bc0107855994-84
# Skipping record due to missing wallet_id or timestamp: 0x1586dae09c4ab90d12518758aece0bd819d8e94b67ebdfb93c3c14f06e351b65-137
# Skipping record due to missing wallet_id or timestamp: 0x1fbfec589920232646d16412c4a74ddb1f361da5ba44be96739b10064cdd00c1-355
# Skipping record due to missing wallet_id or timestamp: 0xc6be75fc61745dd24510c4ca45c0a165e9d88290b35b801952b2ea7760a8f31f-320
# Skipping record due to missing wallet_id or timestamp: 0xd6132b5e558c8e55fe7a37a8d66de84c5fca18c5dda5d5a13464c901436c2b30-337
# Skipping record due to missing wallet_id or timestamp: 0xd801dcbf61464a1946fc46460177566310d0e264a491655d8a61eba770ec4a99-176
# Skipping record due to missing wallet_id or timestamp: 0xfb9559e07f3034f75b122277a4c088028c7dd2685a1711141965d82bf289761d-35
# Skipping record due to missing wallet_id or timestamp: 0x400d1994d24b0b18c40bc5c88a980f759c0375a8c4e34a4ca278e2c98354d4b0-171
# Skipping record due to missing wallet_id or timestamp: 0x53259d10573cbff09bb05642785326f10d20dde731d7d54edb4acce63f075127-158
# Skipping record due to missing wallet_id or timestamp: 0x8b644dab2d8ac9aefef79e3802a9d5a010405d7a465e1b5edab64abadf90744e-17
# Skipping record due to missing wallet_id or timestamp: 0x916d227ea3cd6a097f4ef976f6eee00f4c570823b10c3248f9d269e30f91a4ef-100
# Skipping record due to missing wallet_id or timestamp: 0x967d7b827af76da67b3221c784c650aaa3d86f3b1af27d6d93ca0d9d27ae4406-121
# Skipping record due to missing wallet_id or timestamp: 0xcedb90ef7061217c78366b608ae56f405595da77b1389f01132f042a0ae17548-77
# Skipping record due to missing wallet_id or timestamp: 0x18ca95d7e36009ed2331af8a20f58f4d1c551b7e0c02deffa44890a4ea6b9d37-473
# Skipping record due to missing wallet_id or timestamp: 0x1ab0cf10890a667d3913a7157897997f8918620bc274d3d46618167fe83281b7-141
# Skipping record due to missing wallet_id or timestamp: 0x60bf8613b476af48281bd79a23251c6ef63f0089e44b4cfe29b8d1a86e67e672-25
# Skipping record due to missing wallet_id or timestamp: 0xe49b4c17a01d828c5eecefe1b4fc5a170e6a78ad74262949e1703197b39c34e2-132
# Skipping record due to missing wallet_id or timestamp: 0x056edb03a13c9f49fc04ae663a27ec3482bd0b29be1b14dba244458ff769eaed-36
# Skipping record due to missing wallet_id or timestamp: 0x6cbfbd7ad81ec6a48a5ae9f8f2ab0a566c116cafd05e780d914b63a22e6b9144-73
# Skipping record due to missing wallet_id or timestamp: 0x29912c17c377c978f7241f3d9ca471d02f792d3def475172f8c75d719da45374-120
# Skipping record due to missing wallet_id or timestamp: 0xf10d8306a3eb93e49a0dfb5c7ff89440ea8de1b7df67b928e6056ff263751f47-285
# Skipping record due to missing wallet_id or timestamp: 0xb886ac90ee38a41a0ca576bb26350f337bf87295d13449297b7d6c617fbb8a0b-31
# Skipping record due to missing wallet_id or timestamp: 0xa7887387f53f38cdab52ba1035e6c0a95fa0541886d87d6e7f330fc87e279c0b-128
# Skipping record due to missing wallet_id or timestamp: 0x2ab32c7a1cc5f758257f15db4fa2d8750d966ee266621ef1184746b714c7aac6-97
# Skipping record due to missing wallet_id or timestamp: 0x6f39ab535f4969fe553d7ffd72586d64d4d481e0db42e034f88bd1bab6aa95ea-88
# Skipping record due to missing wallet_id or timestamp: 0x22d4c1f0e767dbb47082096e6424fff67e9d4e16af418331e4a5e77abd0e6339-378
# Skipping record due to missing wallet_id or timestamp: 0x24109f185f1e8ff4617b1c06512ed2992498e9fac663aad99c10e01b0ec22f63-504
# Skipping record due to missing wallet_id or timestamp: 0x4821719a5720960c26219936d76e1e2e408a0b88cfb12e03023c5693c858a262-522
# Skipping record due to missing wallet_id or timestamp: 0x2408d663f8dfeef3f5a6588e90acb1ebfb7f41569e9a7b8d48482a3579a66b0c-164
# Skipping record due to missing wallet_id or timestamp: 0xd9a6d2b35179fd81da19d26517815fbcd39eee6f4039de2653c9f2dc10090318-174
# Skipping record due to missing wallet_id or timestamp: 0xf4b2865476c0dc0d4b55286795be2f5a6bf85c51b5b6ce0e59cf65768186d169-155
# Skipping record due to missing wallet_id or timestamp: 0xfad6b778e6459ff7bfc62935b3f81283398231380dea8ef9b57debaac8d5ff7f-146
# Skipping record due to missing wallet_id or timestamp: 0x2dee423ec22be3d30caba1ee7eb0261142310f2a8c216b1309e1e63c75f8a263-124
# Skipping record due to missing wallet_id or timestamp: 0x4a3a3dc411c9bbe92d3ba33d0b58e1460beb947a8513f537d466b4836d314a1a-133
# Skipping record due to missing wallet_id or timestamp: 0xccd258af57dff67ff7ad983a85f668f40a0cd1f14e39b883c49137c5bb5f8162-122
# Skipping record due to missing wallet_id or timestamp: 0xcdb7bdd30b8ab580e6bf02904b8d11a64ea60d47256b1f19edf1a341c2e28ad8-20
# Skipping record due to missing wallet_id or timestamp: 0xf1892ffd555a16d2d85f93f3c4dea17953701f29131169396a649cb7ea217ae3-146
# Skipping record due to missing wallet_id or timestamp: 0x8326577b4ff697af3a726ed0534dfba3032fc461cf01b2d802d5e650919c72b9-240
# Skipping record due to missing wallet_id or timestamp: 0xf6b05c820de15f60471b419e18c3acbc12b8e9dea110abad833162e7df5a49bf-23
# Skipping record due to missing wallet_id or timestamp: 0x1cf053de1df22f27bd39931faaf634e8d6a624fa05d72c50acbac8666d0d23d6-17
# Skipping record due to missing wallet_id or timestamp: 0x281cbfc4842ad50551b2b5517480ab83e90ae9eb34a8faeecfb4d86b01538d2d-122
# Skipping record due to missing wallet_id or timestamp: 0xad3f2826d9a35d558c1ebca307430e7996f47e644d2de71a83696f9960c0f576-136
# Skipping record due to missing wallet_id or timestamp: 0x8e4e922d1750392b6d160e6d10f0c04dc61c42df553f8e800f8470d495e555c6-81
# Skipping record due to missing wallet_id or timestamp: 0x8f81c85962580f44f8e126270e3403939aaee53b628bea1ce9692b7388454956-71
# Skipping record due to missing wallet_id or timestamp: 0x20c06ffb195dac5da2bf94c9c581c391f934debf2276e1224690795a37160e0e-37
# Skipping record due to missing wallet_id or timestamp: 0xbc05e241d4b142ba7407be7e85b8048c153bede21601567b8ab69d894d40131d-28
# Skipping record due to missing wallet_id or timestamp: 0x835d045f14aa7b6e1dae5407eb504ce60583262a5facfe587225043ef9ddb7dc-195
# Skipping record due to missing wallet_id or timestamp: 0x7c0edc43f358d29d8d656788832708972c5881e0edfc0a02821e967cbf06c519-79
# Skipping record due to missing wallet_id or timestamp: 0x8de8b3207a339d7c08e1f586ebb0ac6ac7d6aec36e3a4716fa88946c1ec358e1-39
# Skipping record due to missing wallet_id or timestamp: 0x7aae703d5b1f916befbf687ab6c8c0fa84272055942a7b70c174cb48645e2950-165
# Skipping record due to missing wallet_id or timestamp: 0x6b00c8780cc7eb55792a8f38553cb99c6698e62e18589babc0f1ee9d2395863d-305
# Skipping record due to missing wallet_id or timestamp: 0x1f37a9ef157619f4b9a0e6e6609d962ad8db7497256deb9184d8e235f6d7e43b-70
# Skipping record due to missing wallet_id or timestamp: 0xd64f3ee8e50188e49ebe83b4b1922d8513711c2b4f5c3b2cbf73c95b78a5fb2d-97
# Skipping record due to missing wallet_id or timestamp: 0x6ae77c7837d771cc4c7801a123445563200b72a260afa8f1fdd2d865a047c61a-21
# Skipping record due to missing wallet_id or timestamp: 0xf168793b210b698d56738feb971c27d1631db9d872a789cc049973b0df45ee6d-239
# Skipping record due to missing wallet_id or timestamp: 0x999cc104a5df613a92debd341f66229f1cf598651910761f6659d4d91ba31382-271
# Skipping record due to missing wallet_id or timestamp: 0xb89fb45ce5978a8677470134391549953eaa9eb4f40e08509fc406eff18ff959-54
# Skipping record due to missing wallet_id or timestamp: 0x7cad57577f7cfb0918c840562cf59b00cef33704ff96a8dff52219212b439900-258
# Skipping record due to missing wallet_id or timestamp: 0x10537acc33f5e835b77e56cfde0d61053556ce7e8692498cbd81805105a48a91-147
# Skipping record due to missing wallet_id or timestamp: 0x27fdc73835d388fc9e126ae8d2fc4462a25a177ca60754951a5dc832de94558f-138
# Skipping record due to missing wallet_id or timestamp: 0xf4c46b1ab9c502b54e53bf0c6c8efc054d598ad220eaeaf137606a1b43b6063b-51
# Skipping record due to missing wallet_id or timestamp: 0x9cefca70f7cc800ea78344bb39afb418c212231b0945f5174cf93fe6ecc6a10e-26
# Skipping record due to missing wallet_id or timestamp: 0xf810189b6c8239ab14078fb10b193a3e6db501e9071accf2cbc6938a701a6083-246
# Skipping record due to missing wallet_id or timestamp: 0x014159bf1c4a459613b49e2125c50eb4797d0fb51872a61b228ff79c7dfe5b61-83
# Skipping record due to missing wallet_id or timestamp: 0x20611842def1dfbdc3918df8033a855514d7579436004da473893a456f964366-540
# Skipping record due to missing wallet_id or timestamp: 0x22e8eda0b9efb8ea927bb19237714ee72278b3a0de503a6788a97e823e556658-186
# Skipping record due to missing wallet_id or timestamp: 0x30fe2f0d6ae3d3ac4528aa8accdbd1b820090628bf029048c758af5b97489302-257
# Skipping record due to missing wallet_id or timestamp: 0x3d1e38837eaed92b3ed1ef07ddfc220ec5ac6279797ff42842b6704059e297ba-165
# Skipping record due to missing wallet_id or timestamp: 0x5ec3e9e2e22d08380af821333f0f2345c5b6b28c6f1f3538183cfcf44058df78-506
# Skipping record due to missing wallet_id or timestamp: 0x6f849a8954ce06b9a654d68deb1b57ca81f4192987d20c390ba5ae64dac367e1-383
# Skipping record due to missing wallet_id or timestamp: 0x70db9eab4f2d4212a9aa6cd50f2ee65627e0289d86f8753587d8a39144727e33-531
# Skipping record due to missing wallet_id or timestamp: 0xa3b726c6d62dd859637e1131d16bc889d610c27111019fabef313aa929af2a32-42
# Skipping record due to missing wallet_id or timestamp: 0xa5d8b5f6bdbd9168a8260eb49a765f7bee373944a4de16cca21abc12e774fce6-18
# Skipping record due to missing wallet_id or timestamp: 0xb5d2c7cd1486b68500e6384d95c2fca6a1d2f1be2e711ee12eea638c0334a165-230
# Skipping record due to missing wallet_id or timestamp: 0xbc4916d59801bfab26d4c50bca47e9c9f184b2ae753b79fcd65b26791c9ad4bf-142
# Skipping record due to missing wallet_id or timestamp: 0xc28171a523e651351df60cc26fb2e83a4832ed3cb93c68980930652187a48986-522
# Skipping record due to missing wallet_id or timestamp: 0xc57fee958d81aab4d1b0580a2064486f731091cd98ef8ddb862f13fb3c254cf8-278
# Skipping record due to missing wallet_id or timestamp: 0xc5d8491e8c4256d1626a3d2948e102e4eed73c6b73a18af248365a9cd85e1c45-338
# Skipping record due to missing wallet_id or timestamp: 0xc8f3e70f5c93b15ef29d138285905384aef9c9f39778364a9969c931de2e81eb-305
# Skipping record due to missing wallet_id or timestamp: 0xd2d7616ab5127a77413f2346938decde00428fd85365d46a1b53f3bf64a2da96-514
# Skipping record due to missing wallet_id or timestamp: 0xd52da6bf5f86b7222045b54250a54f2954f0bd091f5493311210b2c7a2c15b26-212
# Skipping record due to missing wallet_id or timestamp: 0xd5db9c8c6d111feb302c518394167617a645e18ef85def21001fc49479b0702c-360
# Skipping record due to missing wallet_id or timestamp: 0xdcfd198f38464db7acf7f6adaa662a3104b1161ccf4db7a06136bc2ebce47e2f-120
# Skipping record due to missing wallet_id or timestamp: 0xfbc009cc3ff43ab8f4bd2cbf8aa9823a46cd7582cc0a8298e406002697cb0639-101
# Skipping record due to missing wallet_id or timestamp: 0x3f29eb2cc04edd24a7d1c4e1a0b091ab04664504f74402760246c5f27fefa933-315
# Skipping record due to missing wallet_id or timestamp: 0x42fea203b068599be65ad97bfe30f6f83ade7d37d22f07e4960152a88a0a1d77-298
# Skipping record due to missing wallet_id or timestamp: 0x79763be4f4ed160e7ecb6eeaea6258aee75adbda3d416a15c3200ecbdacd254c-93
# Skipping record due to missing wallet_id or timestamp: 0x936f179e7ebdc29e2f28da8e00cb1df44b9e2ae93af353b6e106d21fe6418412-290
# Skipping record due to missing wallet_id or timestamp: 0x96812aeda54c16fc9cef0d23b7cea30796c1bc5294f3ea69580018c885ff8a02-281
# Skipping record due to missing wallet_id or timestamp: 0xbdfe2acc0914742777d546f902500cbd3c5d13d23c44351b6d754da90ca0b579-306
# Skipping record due to missing wallet_id or timestamp: 0xc64e913729cbe2ba4995c77133b004f511cfa099324c06d0fd394190f157c2f6-169
# Skipping record due to missing wallet_id or timestamp: 0xcd1d16b6c7c94de0ecab1ce6ef8ea4c6cbc17f4bd9573fdcbd8e3093214f8b9f-101
# Skipping record due to missing wallet_id or timestamp: 0xeabee4830869e1eb051e685d2573aae719dfd48a561d594dcfc888738d16aff5-84
# Skipping record due to missing wallet_id or timestamp: 0x3ab56ea1d03b5da481fe1e5cda7e3ad57dff8a46965a12c4d7060457576fdadc-98
# Skipping record due to missing wallet_id or timestamp: 0x53cbf68e01f29b9718ed26efee4e0a57888c1d744557f540dcecff8da3f8c28a-117
# Skipping record due to missing wallet_id or timestamp: 0xba644bb6107078e8e37007053b429940559e7a1e5a68f12bee8478c96d44ef1b-87
# Skipping record due to missing wallet_id or timestamp: 0xe8e8b95d42a85271cc825aebeac9306c7442f85596df3adf981a855623ad8716-108
# Skipping record due to missing wallet_id or timestamp: 0x1d7a349b2bda26ce51c99a745b885f6e64b2194d913400c360fd643240dcd6c1-219
# Skipping record due to missing wallet_id or timestamp: 0x2dcfaa9ceaed0d24d1f7995aff39e854be96a71ceb7e6d4ad892991a7e495413-276
# Skipping record due to missing wallet_id or timestamp: 0x9b2b5528d567a0b0a999a1dbea584bd278a95b86c25eefbba7335a7abf5c474c-239
# Skipping record due to missing wallet_id or timestamp: 0xe726a33f94474657e8c41d6195e8ca0ecbd602cbb7bfc2a3446c103e7f481ba4-258
# Skipping record due to missing wallet_id or timestamp: 0xf2e781ccba087174156e65d15f944c8adece183dbf962c2138228bc8311e3650-89
# Skipping record due to missing wallet_id or timestamp: 0xcb9e54fb40c4b83afb1bf25fa29f30bdb46b8f2e91ee6b78318134a7c3035786-22
# Skipping record due to missing wallet_id or timestamp: 0xf8c260bd7b3d22722aed7262012a31e424d0ed85b0c0bec2ee4c298dbdc0b23a-194
# Skipping record due to missing wallet_id or timestamp: 0x3081189ea8364ff04e870343fd6d3adf2aaae88b0faa67c742514c86f3dab484-177
# Skipping record due to missing wallet_id or timestamp: 0x180479df6d400307a16d4298251a161f686daf297f7bf2a20cf795dd37e79ff3-20
# Skipping record due to missing wallet_id or timestamp: 0x8277d77909eab9d0aaf5129dd96f294d98369dd5dcaf92fa1ff0d2acd1d0efd6-149
# Skipping record due to missing wallet_id or timestamp: 0xcf96106e42acbfc562297d4937e7a4a0eefb554107800976e73c10f44b38bf4f-34
# Skipping record due to missing wallet_id or timestamp: 0x6b8317057442c9146fed3ca91ce5fbdd7928c90358df93bb277c44584c2bdddb-10
# Skipping record due to missing wallet_id or timestamp: 0x286e2178aca624906bf71f4fd18332ebfc1f220ec27df95bcde7961dcf9bea86-291
# Skipping record due to missing wallet_id or timestamp: 0x666b694f1de522db84a19aaa553ac5bed86adb6aa2d716164395a19d12c12655-140
# Skipping record due to missing wallet_id or timestamp: 0x27222e95234a78d07ab97b789a686857a1398cc74aafec96737d1a797e61a326-113
# Skipping record due to missing wallet_id or timestamp: 0x20bd13d52842352ce2c17068634b8279a3a0293b3ea680a8b6cae690e0e35a66-42
# Skipping record due to missing wallet_id or timestamp: 0x5af49585a0a7f580c1ee4c5415419b907964d1b45c31d4d0d59078292668e88c-10
# Skipping record due to missing wallet_id or timestamp: 0xba62189d847fa908ab2af6f2b38e4fca9f05351ce2c566fe85cd83691ccb3b46-31
# Skipping record due to missing wallet_id or timestamp: 0x3f3c535b5eeb4d43ad12bb04c8f181cb0a453f448fae2e5bd6e9cfa1e68f5370-90
# Skipping record due to missing wallet_id or timestamp: 0xc0efd71a5b776919e5924f2b02fd006e5fdb892c8b9cc7898c688cd1f0178d4f-23
# Skipping record due to missing wallet_id or timestamp: 0x9f8ccb5c0d653e8c88c2bb61f601312ce9fbcbdd86a2946bb1334fcbe4ac10d7-18
# Skipping record due to missing wallet_id or timestamp: 0x5c3ce11ecb6e6eebeda2537e9cba863c3d7c05081a17ee3ed6273789750b7358-13
# Skipping record due to missing wallet_id or timestamp: 0x5c3cddfe77c278434f37853b50611e9a8cade079b4fa77470bad9f55bc39eb04-13
# Skipping record due to missing wallet_id or timestamp: 0xe3914e9991b3995dd02bd836dbbf7d287c7d1afb608078a689383969359e6f84-10
# Skipping record due to missing wallet_id or timestamp: 0x22e4cc0006ba181acdf6fe079742914b15dc45c13e5f9e0eddcd8a55201aab67-13
# Skipping record due to missing wallet_id or timestamp: 0x335e50043552066cb19fab7acdc87b9875c346ec01ddb2046dce5ec0959541d7-178
# Skipping record due to missing wallet_id or timestamp: 0x1984daf08be475d462e7f7848135a86dd09c47239cc9587658b0e1b9da574c4f-17
# Skipping record due to missing wallet_id or timestamp: 0xd467534bf433db0c4e9ca3d173766d5e5c4524b8c406216d09f620e8b441291e-35
# Skipping record due to missing wallet_id or timestamp: 0x68719ed40ddba93ddb473e337c47828bf369c49b27cf03275ec8e1dc041e38f6-30
# Skipping record due to missing wallet_id or timestamp: 0x32329f329346652dc85493b87836fa96ff96ccfc78022649ea26273c0af3676d-17
# Skipping record due to missing wallet_id or timestamp: 0x669068e627319c541e9d4f0650e0a45741020a1ee550d5a721194aaa450b3b49-439
# Skipping record due to missing wallet_id or timestamp: 0x2215c3efddb78c74d139f0f40027435e2d4dd3a8c11de265f771d7da05ae6b65-44
# Skipping record due to missing wallet_id or timestamp: 0xe620b63d8d58e5f4f1b12f546e15151e54bf8425cfaba10e2b051d19039553ef-202
# Skipping record due to missing wallet_id or timestamp: 0x3f39204c012c45b9d9368c8df01afb010a97f923e63039ae6150075c79e724ec-41
# Skipping record due to missing wallet_id or timestamp: 0x113ddf28b5f96ae94559e623ae6d858527771a504237ba29a81bf7045a71bd9e-10
# Skipping record due to missing wallet_id or timestamp: 0xa92cb0cc2ec84c4a9f50aecbf4baefb0d19a84db4c2765966829cd2a57fd6006-64
# Skipping record due to missing wallet_id or timestamp: 0x602e22ba177a04a968ffe9e194a9882981f42f2046a1bcfad29c017068b7225a-23
# Skipping record due to missing wallet_id or timestamp: 0xe9e03d6f486bab50741fe23aa9f3ec3d5f0a2621f93e0a4dd782ce8869310c17-10
# Skipping record due to missing wallet_id or timestamp: 0x74aa3897539eec8234dec26c8a0ae5094b896d6f8a14e5ce202aa35dcb7fd02f-64
# Skipping record due to missing wallet_id or timestamp: 0xc2c7782d61c63bb30e246830d72ed03ad02370846211df466116f67d118c0aa5-13
# Skipping record due to missing wallet_id or timestamp: 0xe9183f5ca75b3d29d322d31b5f17153a740de7790908b44617cbe7b58c921550-10
# Skipping record due to missing wallet_id or timestamp: 0x2a4043b5119d8ee1d004277dd8422a86a564620bcf87955e6faa6307250ed7f2-430
# Skipping record due to missing wallet_id or timestamp: 0x47a9e184d65e8580c73b29b5cb89e635cd2ff0fa8a7ac228d61dcb837e0e71b8-441
# Skipping record due to missing wallet_id or timestamp: 0x535c751b6df6e824da0616af6bea8825086a9601d3dc2aa09f122f0c7d9509d9-14
# Skipping record due to missing wallet_id or timestamp: 0x10c1033fc00e418ad78983bcacab459339079593044e0aa7e746169eae314b84-23
# Skipping record due to missing wallet_id or timestamp: 0xf4049efd9ba39ec19e25031602ef9a7655b0548e5f53ed9f0971820526be356c-10
# Skipping record due to missing wallet_id or timestamp: 0x62cba0eaa825db9aa9fb3049de35b5fab4a352112c7e21c838cf9a4a681094b2-55
# Skipping record due to missing wallet_id or timestamp: 0x611c7b3ee778295484293ffbfdbcc523df5455ed3311c5905232816624cc1cad-38
# Skipping record due to missing wallet_id or timestamp: 0x1623dabf79fb267e537631951ff136d230c43994311faea4bcde3d4c00cb321a-32
# Skipping record due to missing wallet_id or timestamp: 0x0c920eefe0046d7e571ac0645178eeb604a752893687aaf569b4ca58924988df-10
# Skipping record due to missing wallet_id or timestamp: 0x36e7dc6d59e8692ad0b431f540ebfd5f4370214a923fa6cedd7d6f937e049573-10
# Skipping record due to missing wallet_id or timestamp: 0x73dafc0f7e29e802339abbf631f502a717b37c2bc273fe9b58fd78d4c6b341a5-32
# Skipping record due to missing wallet_id or timestamp: 0xc426426a674a64ccea4c4bc93ad9465b9f9ad23f616e5afbbb44f53781b1e3e9-13
# Skipping record due to missing wallet_id or timestamp: 0xe8bdf6679c62b6e2b4e02e893491e1c8bcf4b0dbe312caab7719e9e08f4f7b9b-50
# Skipping record due to missing wallet_id or timestamp: 0xc97023f6a6d4660d66bbc297107be912e358808a711b47aea2f90a4aaacb4631-110
# Skipping record due to missing wallet_id or timestamp: 0x689d5f541113101a88eb3fc88318ef44e87e037c821bcee6f6e0fd8ba30972bc-29
# Skipping record due to missing wallet_id or timestamp: 0xe9bc65b91d5b63c73e76cbdc4bfe90a3aa2d87a88a6c3970060bd81b16051917-35
# Skipping record due to missing wallet_id or timestamp: 0x58f7b4e813991c22bbb8cc248a6aa29da7bc218103af0dc3027ab8e6c245fbf3-36
# Skipping record due to missing wallet_id or timestamp: 0xd5f1dfdf2f98db0eaa33d635cf0745d01b1ed28efca73427bd9661d9c1e3bb84-85
# Skipping record due to missing wallet_id or timestamp: 0x70a6c4aebdd4f3d92bded1d7009a1d49420e7fd4cc96abdea00bd433501aa6f4-18
# Skipping record due to missing wallet_id or timestamp: 0x5ea06575ce0619d52fc33b81e2f80e91da8042be46835e86d90b6ed2bed7051b-16
# Skipping record due to missing wallet_id or timestamp: 0xa95d3ec211826d95c990dd6eee452895d6d0303278ac2be20f82cf9b5291cbd1-62
# Skipping record due to missing wallet_id or timestamp: 0xd356df3403490a1cb4bd17c27e289d0bc8e4d7612e3f2d8d9e024f8513d03aca-93
# Skipping record due to missing wallet_id or timestamp: 0xec7b62cd4a8373694c3fd7e84c08244df9dd2316e2b366b2b079ce711692ee3a-13
# Skipping record due to missing wallet_id or timestamp: 0x2310ae55aec68561cd9e7095ab3a260f16a323d226bc92a4dead0374f0b10314-88
# Skipping record due to missing wallet_id or timestamp: 0xbe62223e8a4c15e53758842b73694d74316f3c25e3e5fa5449135d719ffc8cfb-19
# Skipping record due to missing wallet_id or timestamp: 0xfd6952a8672c627d29b50832305356119b6b215a6283efe6405c296c92a458d9-10
# Skipping record due to missing wallet_id or timestamp: 0x61e30e9201ee37b2c7acb543905f561ba13c939b32e9cf4d74ed85395532fa29-10
# Skipping record due to missing wallet_id or timestamp: 0x4e686cb388108983cdd15270b9d24b49e9d80591794ea172a1152573772874f2-49
# Skipping record due to missing wallet_id or timestamp: 0x6b444c72ae7f33dacd7531a79697aea3d6af04ec7b24c0bd78d25ac33bf6b853-10
# Skipping record due to missing wallet_id or timestamp: 0x6d6c18a11f8cb4f1a14931dda4a33d95e40f7389a6bf8183da444920f9294cc1-24
# Skipping record due to missing wallet_id or timestamp: 0x9e6ad3b063cc46209e0120681e2b148a9fd0e13436aa618c7ff720056e2b3bed-56
# Skipping record due to missing wallet_id or timestamp: 0xacf5d0a1d8d1d2099ea55a44de57aae5e65f3ab38a5cad320f209f7813321b94-10
# Skipping record due to missing wallet_id or timestamp: 0x80ecb389b3d07fd9c2e11f7b7218d51a8d508130ca6c1fc41d83f25926bf437c-23
# Skipping record due to missing wallet_id or timestamp: 0x4e8c966e3aa8cb0d6ba15b0f06f76801d3ae9f19503a935a8e07d0b092834c24-54
# Skipping record due to missing wallet_id or timestamp: 0x75e47319170f49235455c968af2f5c6ced4a92790c40a1aac4717d91e5f6ea60-16
# Skipping record due to missing wallet_id or timestamp: 0xf81104482061eb49bea02ce186965079f86774e2416504d74649cb0622052a4c-34
# Skipping record due to missing wallet_id or timestamp: 0x4de414ce93d5e891b03faf8c3c9e63ec9de709fcf5dba110da37be4ac12917a6-267
# Skipping record due to missing wallet_id or timestamp: 0x55d62537e14a1afb70674256dbd2922cfb69b707192611218dd993c8f5516cb0-257
# Skipping record due to missing wallet_id or timestamp: 0xff8626f7f17fc2fd95d819267fd36e04ab76b483bb139d942088f7ac1f38eeff-10
# Skipping record due to missing wallet_id or timestamp: 0xce5b72e0bafb8412ac16f5f2bb3f7f500da55468e7d7663288fd1bad15b5c3ae-13
# Skipping record due to missing wallet_id or timestamp: 0xe014b9a84d83b6130d939bb090429803cb58dc88e494377d3cae4297ef718d35-16
# Skipping record due to missing wallet_id or timestamp: 0xc3b901c1cbc3a5c4b6012c56a89483313f38edf5806fe49e703fba4652eb0157-23
# Skipping record due to missing wallet_id or timestamp: 0x6b86a03fa7dcca50d0f528bcc2298d0f393e8baf0a44b2d3e79da8c190f6a090-10
# Skipping record due to missing wallet_id or timestamp: 0x39b41235238f3e715bacbd9fdab833e221ee69fe026adcacbd633c442271e1b8-31
# Skipping record due to missing wallet_id or timestamp: 0xc8d66ab351a2563040b23d8aee6275ca3dc9a6e055c65a455fb9dcf6b4305644-16
# Skipping record due to missing wallet_id or timestamp: 0x0dd3fb4d79f50cb3c6d3b820a27f390426815f8501062d51c847ff34683fafb8-41
# Skipping record due to missing wallet_id or timestamp: 0x0f5c582273a4c65dec2ff65eebe589f47c433c5867974ced6a4573a6b95c0a17-10
# Skipping record due to missing wallet_id or timestamp: 0x131747e31e8c3d805177d1c33da094cc3bef5d207bdc2ba953b5d74be8e6a547-66
# Skipping record due to missing wallet_id or timestamp: 0xad044f93f5a38d137ea9488cd34e900857fe1665f99c4f9a0e0ca57d096328e1-68
# Skipping record due to missing wallet_id or timestamp: 0x0f9cc96224da18c209e3d1473c5e622cd1724fa5dfdc16799a57824e65384428-30
# Skipping record due to missing wallet_id or timestamp: 0xbc4c4e4282bb027b01bafadb1aba3005a6b0b5d9dbe215bffc95a703d87f77f2-21
# Skipping record due to missing wallet_id or timestamp: 0x4df7199eaded845e965ae55c06014e3cf09224eabe17cdf4d17f7be214f99ae1-143
# Skipping record due to missing wallet_id or timestamp: 0x5fe30e5e2320d8913804e70c906aa0dacbf2c4c357433d0dffb71075137af53c-123
# Skipping record due to missing wallet_id or timestamp: 0x970794cc209edab177459604eb4799020b88251cef3a6cc8735bfcd3dd956a89-50
# Skipping record due to missing wallet_id or timestamp: 0x8eb0df0d7552be3dfe2b3387a4b9b1bfd53d917a5e704107609ed6faeb0d2998-26
# Skipping record due to missing wallet_id or timestamp: 0xabcaaaffaf4c5e257baa3c9ead41d05042464ae1c3c16668e7c3048f75904246-37
# Skipping record due to missing wallet_id or timestamp: 0xa0a60da22c9826b93bcf7f4de711fa1379f392f5caf71efc23a1e32f700ab1ad-43
# Skipping record due to missing wallet_id or timestamp: 0x7405f93261dd2a449708c17fc8b9ffd3d192b6d427563618580de12350481fce-114
# Skipping record due to missing wallet_id or timestamp: 0x4d26f117f5897ab2ade87642a599bdf4f014416f75b977180e5bbe0604c58f78-10
# Skipping record due to missing wallet_id or timestamp: 0x70784dbad6b7d23caf3f4163312c1a5437be7d756a52c5dc37356c144e8ef852-58
# Skipping record due to missing wallet_id or timestamp: 0xe1cd280bf106a4fb2b62fd001a52bc5b643a41b3b185f0286e1f6e8c5fc52920-95
# Skipping record due to missing wallet_id or timestamp: 0xcb3e662e48ec8c01ef293277afbc1accdac439c9d7e075a0d8a5ee07268c733e-124
# Skipping record due to missing wallet_id or timestamp: 0x32ff0e835c998b2dfaeaa1f485b216011787581b7a36cd745676121d6a2bc61e-446
# Skipping record due to missing wallet_id or timestamp: 0x871a14d254617a8d2e8a0a022104b17ecba76ffc7735251b19221c2a7439dedc-427
# Skipping record due to missing wallet_id or timestamp: 0x5e66c84c6aba7d57ddda606e02f7b30e914675aac29525731d579c8d4b1e4304-67
# Skipping record due to missing wallet_id or timestamp: 0x9de823972c56fd41e71bce78b380826063bbf99376cb5911c945973179dec1cd-57
# Skipping record due to missing wallet_id or timestamp: 0xd98465a061ccaee99bc6c7be1e123e2da9a2ac6147960ea85c0853d330bb607e-77
# Skipping record due to missing wallet_id or timestamp: 0x066769cd5dc2c26c0eaabfcb798f4a69868362dca54ab65016f5ebdf5f237679-517
# Skipping record due to missing wallet_id or timestamp: 0x0c358420a442c012dfc3fec127d6d871868a6de9bbc57f9b9a6fd7c83f91946e-500
# Skipping record due to missing wallet_id or timestamp: 0x1400ecf12d473f7471efa1723aa64a3539866a74f7c5be6b15835f751ac87e79-270
# Skipping record due to missing wallet_id or timestamp: 0x3edc81ca0a67d188deb74f4246c63ef05c7bdb5156277d635bb1dec03b86798b-293
# Skipping record due to missing wallet_id or timestamp: 0x60f6e99954f19a4cb2793f08833e68610fc1762daec9b1ba9671a18776281386-247
# Skipping record due to missing wallet_id or timestamp: 0x725919a11910e9d5ad0145218d27432566bf3ae7bcc928a53a6a2019cd353e5d-340
# Skipping record due to missing wallet_id or timestamp: 0xb68eb210f3bc6c2b13f6cb2977a100efcfc7b817a5c0096226c59153e1d79637-19
# Skipping record due to missing wallet_id or timestamp: 0xba6788ccc26e8f540278ff3b7b1b9db35c558824705b14feb417a9976c4c4bd1-492
# Skipping record due to missing wallet_id or timestamp: 0xd028e92a24df7d3e2ca991ce1742787519638e7f8860a15195383fae3a4b8582-362
# Skipping record due to missing wallet_id or timestamp: 0xdbe4f8e40527f52fd838df69ea54779f6d0671c77e3adfd036287aa531887e81-70
# Skipping record due to missing wallet_id or timestamp: 0xf260e11400dedabd4e7272aa30af1f3d43e886738296ed83666dd550edd19500-508
# Skipping record due to missing wallet_id or timestamp: 0xfa8c66fab85c6147b4b5dae55dcb3ea516b2eba19185561f76e556ca0f72ad80-319
# Skipping record due to missing wallet_id or timestamp: 0xfe91b158d8d87c1e7a6d59fea16550fc054235b15547ddcbddb3cc613cd848de-44
# Skipping record due to missing wallet_id or timestamp: 0x143fa1f658deffe5dcd3429a178102e7ae7d49cae138cfd6dad761c8ad5d6d34-118
# Skipping record due to missing wallet_id or timestamp: 0x1a36138883201dc738dd31a832ffa904d5cf4ac2ebf67e8a9d793d93a01ceb26-134
# Skipping record due to missing wallet_id or timestamp: 0x2281f9cefdc72cd0118f18b14fcf41fde3554bafb3b9de83d2fd592a29bb13dd-32
# Skipping record due to missing wallet_id or timestamp: 0x2c6df878f4838e36a4c56893989c45ab3fcb1f0d0f195dda0af9273f0bd4417c-81
# Skipping record due to missing wallet_id or timestamp: 0x42221a81dcdb362b0d66fae89d64c8a606feea554c004847f03691e9aa7e68fd-91
# Skipping record due to missing wallet_id or timestamp: 0x679b23e1a07fb63b0f29e9380f3e48faff3a96764d7af512ae889b0dde06be43-99
# Skipping record due to missing wallet_id or timestamp: 0x74a82637514405893afd922b0f4a566512985e5804bbaee92747c6b055beb0c1-126
# Skipping record due to missing wallet_id or timestamp: 0xf616346bd3f9a17906e8b4160f79efde800b626b024ab33876b71573558bb8da-108
# Skipping record due to missing wallet_id or timestamp: 0xa34bd4b27649c3e2399cbbb8742b8d05ca83651d0502ceb7797c46de62c9709d-100
# Skipping record due to missing wallet_id or timestamp: 0xca82bdbdc98a81aeeadd31319bc25bd9ddf46450e2c11b6febcbe4cdc19cd85b-89
# Skipping record due to missing wallet_id or timestamp: 0xd6f68a3433494c2a778856d4dfb20a4575da18748e424925c660e79f76626df5-93
# Skipping record due to missing wallet_id or timestamp: 0xda675b7ae8a1c976da48ae91147b2118d7a59b51ffd43f7b24082f12c43c6789-34
# Skipping record due to missing wallet_id or timestamp: 0xdb045b00c83f89bb8f3d0b0f26348b133a89fc3ea20f164ec422b2643823ef53-83
# Skipping record due to missing wallet_id or timestamp: 0x49d8c06b2d1619165f23f5f6255fbab72a491ff286f8f84d4e380f8665642bdc-122
# Skipping record due to missing wallet_id or timestamp: 0x4a329b440bdb3eb556cea657bd115b6263cbaab1b497d28dd7c3c91466a7cbbc-91
# Skipping record due to missing wallet_id or timestamp: 0x9c77d3c5293e7d623713f5fad4c681095e24595eb64987b5af71e49034d4f49d-139
# Skipping record due to missing wallet_id or timestamp: 0xed65f16ba670a3b53ddbdaa6fdaa37b23effe80bd672a3527242cd1f9d003e15-108
# Skipping record due to missing wallet_id or timestamp: 0x1fac8c06ccd5bf694251d47796a44737b514d0f5020261f181e42cfe17c0f0ed-111
# Skipping record due to missing wallet_id or timestamp: 0x2b5da0535e11998ed0dc5c1748ceb180e4fa025020107a80a390385189ef4883-90
# Skipping record due to missing wallet_id or timestamp: 0x2cf4f273dd6ecc8890d4388aae3418d37fd4fbb2cfbba36f0e4d98003ecbc563-161
# Skipping record due to missing wallet_id or timestamp: 0x309763cd333a621a372f063be4293c543653e61154c6ac4d46e5df2ef489b6ec-99
# Skipping record due to missing wallet_id or timestamp: 0x3338514c240ae158187457e5f52c16b097974b044efa0ec324fe0edac369398b-80
# Skipping record due to missing wallet_id or timestamp: 0x460becc11b8cf780c5f4cf94def0f793dd45fa215a77235e57771e65402f3e18-170
# Skipping record due to missing wallet_id or timestamp: 0x482b8e818127a8eef65b0ab2ece78c1b21f6a5b165faa97e52cdbdbc8bd06f74-153
# Skipping record due to missing wallet_id or timestamp: 0x9342708fd318b6648188b7304d32f5f840083077842f57b3518b66a92f1f80a1-135
# Skipping record due to missing wallet_id or timestamp: 0xf49a9619578bd30d2fd51f8c41d96f7bd125c54b44eaf13577edd223c08a592f-144
# Skipping record due to missing wallet_id or timestamp: 0x1a020f108bd15b78b4217e760767f1fcea21d8e9473545c1278e08217a655b8a-157
# Skipping record due to missing wallet_id or timestamp: 0x2efa017165f82822b6aa436d0bc0f232db675cc6b6ab96755e6f76aa20347744-332
# Skipping record due to missing wallet_id or timestamp: 0x89ef28028dce2fde19d96d24a9c609095ed8dac3454173743bdb60ab1fd282b6-341
# Skipping record due to missing wallet_id or timestamp: 0xaeb16a7e625a8d11614e27d49e3fbac628a00c5d07455379f4f1ba46af96fc04-130
# Skipping record due to missing wallet_id or timestamp: 0xba0a9d5ce60763c721e79947c9b289abefb3aba43c2b6a2b95b318daff951d69-323
# Skipping record due to missing wallet_id or timestamp: 0xbf1b2d5732fe03e659594bca9ba4123fc2d8a6df42b44bcd88593528d5518ecb-31
# Skipping record due to missing wallet_id or timestamp: 0xc11b72f9d97011427046e925ad25f1c402be9b991dcab75bb09ed12033688cf2-16
# Skipping record due to missing wallet_id or timestamp: 0xfa6275aac5dc7a3280b0eb6ab4998a8e34891a036a0704af8dcf2bc662b0ca8e-140
# Skipping record due to missing wallet_id or timestamp: 0x326a2eb5f29075ebab00d42e765c9b4cbdb67b67b17d0e73cb4383971ec643a8-43
# Skipping record due to missing wallet_id or timestamp: 0x5393003e785de546b5fa6d65084d9502fb2b2fd565d45ceb463eed1100b7763f-52
# Skipping record due to missing wallet_id or timestamp: 0x759837c1fd481cab14b8717be50bd414a2ac49467351fa0215a02dad65f51c40-10
# Skipping record due to missing wallet_id or timestamp: 0xbc26916ae3a0b4ba8ee18ffa54aca0e0cb92ba005ea0633b8dc7eaf38b108581-18
# Skipping record due to missing wallet_id or timestamp: 0x18b059e36741ef36151d568356a483ee4427199eef6b9f5058cbd88a1ebe305f-25
# Skipping record due to missing wallet_id or timestamp: 0x273688af430c91741862e1bbca7420a58ead8b0b9769614d5899924bb71a790d-395
# Skipping record due to missing wallet_id or timestamp: 0x3c4752e7ca3072f7f6f96721dce7bfe34aa85fa89397273f21d3252db29a33bd-14
# Skipping record due to missing wallet_id or timestamp: 0x3dca19700f9ce9a85c009b2e5d31fa763823b846abd3bdd400b835bae3a26224-64
# Skipping record due to missing wallet_id or timestamp: 0x3fd313f46fb0f86e89359b2ee7f27864152dadc245228584c9cda1b151412575-45
# Skipping record due to missing wallet_id or timestamp: 0x7d2859209150f91342d15ea1143fd64c02c47722a9f4def8216177289f3bc2c4-404
# Skipping record due to missing wallet_id or timestamp: 0xa8be4fdaba503e3477aa6a203f5d63d9008b7eba9b7e452c2bc40865fb2d59ab-82
# Skipping record due to missing wallet_id or timestamp: 0x49a35a9fd033986714cbe4b9e07fc24916a2094b6747215a989e5aea271a0915-78
# Skipping record due to missing wallet_id or timestamp: 0x93e9806acc7ebca996f3ba513521be52edf845a19881b0efe7a8e6f256718cf4-102
# Skipping record due to missing wallet_id or timestamp: 0xf8ff0925be0805817efecb9b5a295f9b3fb0af62467b9f432df47b3a9dd099de-17
# Skipping record due to missing wallet_id or timestamp: 0xca7358145720d8040f2a54ca831fa02cf3ea18ea14af5c82ddfa3b633e3fa1ff-16
# Skipping record due to missing wallet_id or timestamp: 0x09273dca98e0421266e23c480016b4598428f4b81955f1fe8b44180f7274d1dd-19
# Skipping record due to missing wallet_id or timestamp: 0x3b88b991ada16d047db42abcc61e7ea3a099c8e5a1da9545b29320ddac4f32e6-132
# Skipping record due to missing wallet_id or timestamp: 0x63955e9a58fb160773afa5e6e56d44df052a8db7be212cf8eceb79bac1a4a8f5-115
# Skipping record due to missing wallet_id or timestamp: 0xbbbe9502f44523761abfd20cec77a86943ca8d84b855a1d6999503852f81da7e-94
# Skipping record due to missing wallet_id or timestamp: 0xf676266b6ef0d661ffa1ee3758632ec47266128f9220a38be165953b2758e3c3-39
# Skipping record due to missing wallet_id or timestamp: 0x4a3a620577309be04ca4fe4ff007b8816796a3b73906b0db0fed0ed14456c941-20
# Skipping record due to missing wallet_id or timestamp: 0x4a3a620577309be04ca4fe4ff007b8816796a3b73906b0db0fed0ed14456c941-33
# Skipping record due to missing wallet_id or timestamp: 0x4a3a620577309be04ca4fe4ff007b8816796a3b73906b0db0fed0ed14456c941-46
# Skipping record due to missing wallet_id or timestamp: 0x7153c0f2432e40e1d3915b23c80827e5f49585efd3f610fe4f957b6596e21030-401
# Skipping record due to missing wallet_id or timestamp: 0x3eee36713ca21bf20b1dd89f3581b6c8051abada119499927368f0063be9d094-54
# Skipping record due to missing wallet_id or timestamp: 0xa32a07b2ad2591b8d4002af9d6a52a01af2eba33120fec087600f6ad7f486496-25
# Skipping record due to missing wallet_id or timestamp: 0x43e8074f0738ef336a6c41217ad20fd9f7edbd7c04689b79cdd5ca17517ae370-55
# Skipping record due to missing wallet_id or timestamp: 0x51e753e163b893bfc42e8f4a707263ee5ef4e2fc5e48ee4b386d465b8bccbd46-64
# Skipping record due to missing wallet_id or timestamp: 0x335b19587ae9c21714bd9ee7e2c082f506e6024ced605043d000818f4d669ce0-66
# Skipping record due to missing wallet_id or timestamp: 0x4fbcf9656b0f69ba4a79c94fd4cb03c14a6047f43d0afaa48037bc4333c54061-105
# Skipping record due to missing wallet_id or timestamp: 0x500ce9549e0afa7fbd268efeb9044d36c5f310ad621bfd25cab1702abb7eca7f-157
# Skipping record due to missing wallet_id or timestamp: 0x6cd013786578d793e29c7e3daf0d3f69a37c0482cae11191f044028eb7d45bc3-148
# Skipping record due to missing wallet_id or timestamp: 0x96e992a06032d2852205d47baac038a1c53b2ca695337ee388c9537f79eba3bd-166
# Skipping record due to missing wallet_id or timestamp: 0x61885f2d5491aade779ca5ad48cc25dfb3d910a357d8b5a111cf5736e5817b61-253
# Skipping record due to missing wallet_id or timestamp: 0x05007c90ed8171c34606d6864b8bf00d63f83a1d0d4a20df6b47f1a685b5667b-496
# Skipping record due to missing wallet_id or timestamp: 0x0bf6d4e1d12039310895f8c610c2515d3cb64e0dc9b512d53997c689be2d50f7-219
# Skipping record due to missing wallet_id or timestamp: 0x27aa48d00d5441f4c9ecfd6ff104aac71321556a8f5e5f4d30850aa3e277eb54-13
# Skipping record due to missing wallet_id or timestamp: 0x59ad5076c6189d2e20a2fe8c2efe97de26a8f79cc29324a79d016ed67adba2cc-283
# Skipping record due to missing wallet_id or timestamp: 0x9972111bf28e69ea2d2cc7851e2cb1bc6c154d211900847eda77b6d7c054d3fa-165
# Skipping record due to missing wallet_id or timestamp: 0x9a18664ce6f878e5c756e2b9a5998e7f384e2cbb02123055c2eeb458df89a734-551
# Skipping record due to missing wallet_id or timestamp: 0xba0bbb0889b4b1fa243a8ff6f43ab3d61d40efa843bab2e37c6b034cb5d19786-189
# Skipping record due to missing wallet_id or timestamp: 0xc3395357d8a425f8ba248d528dba3806d7c883e790feed5163d87fb911004e43-479
# Skipping record due to missing wallet_id or timestamp: 0xcdfb61751b6b613ebff1bf50c56df8c5538467552bee719edce0e32316f9644f-522
# Skipping record due to missing wallet_id or timestamp: 0xe14308a95f47eb7e70a378f5be016aab530fe1e2c530421bd7954ce1203cb6ce-31
# Skipping record due to missing wallet_id or timestamp: 0xe6dd17f0c9f8da13f101666754ee60b96e8228cf6ff7d2991f2ee4b7c07a9d27-543
# Skipping record due to missing wallet_id or timestamp: 0xedd8886a8c6e8a6f342f4253c859d7cb4868f6704de388b28ec0de3ab448dd70-146
# Skipping record due to missing wallet_id or timestamp: 0xf0385c5271513435d6da9d2703938be236abbe7f4d98f29a5d6a194b590f6ba9-535
# Skipping record due to missing wallet_id or timestamp: 0xf04275915a93c1fcd10bf21eb7e7328d7d1b8deb76fd9385dfa8827d9ca70f9e-250
# ...
# Skipping record due to missing wallet_id or timestamp: 0xd8f459fa7152e2f6002ed0e6624c87d603f0d7f52ae7fd9b37688e57b50e191c-373
# Skipping record due to missing wallet_id or timestamp: 0x17a0a2ca6aa6529a18b4cbdd827e0fab1904d760a85ee9eb9949ac08d2d2e272-161
# Skipping record due to missing wallet_id or timestamp: 0x77f68dd10e3a2e49089a5d244cb32e1bb1852ba69cf61a1f5e81c6cb67305d71-479
# Skipping record due to missing wallet_id or timestamp: 0x21fbfc92b25c54639bbe39695a3d4822ce8417d157589d4a64b29f53f647bb0a-265
# Skipping record due to missing wallet_id or timestamp: 0x8aa31e6e59e58596c0d4979fe038ddf2d9a5e46d12af0bbc4529f3877a56e58f-409
# Skipping record due to missing wallet_id or timestamp: 0xd18d3a8a9efa6ab591f51e46222778529dd113b2492775f8992d134f93868133-23
# Skipping record due to missing wallet_id or timestamp: 0x0c0f299e800bf807f47f9f1e1e070aa220a9575f25c854829652f3ac4610a111-193
# Skipping record due to missing wallet_id or timestamp: 0xebf8844f0ee21ae30050fd47ecbc11b21324e7dd12618cfc98e19d919d0d1ff3-62
# Skipping record due to missing wallet_id or timestamp: 0x4a3644af1be06bc9aca069ed1aaf183a82d7f5b8003ea61eab8b4050e75db4f9-138
# Skipping record due to missing wallet_id or timestamp: 0x18cfba98a6c378d5b3cf5c69b6706f81e7220d88e45942ab43dff02557e58215-343
# Skipping record due to missing wallet_id or timestamp: 0x308a92e8d58dedc2b224092bc432b6fab2ffde66219050b0e0652918550beb80-306
# Skipping record due to missing wallet_id or timestamp: 0x991c8052491a7adbe83d82f8ca1afab046edb6716d1e1719f45de4671bdd2538-646
# Skipping record due to missing wallet_id or timestamp: 0x4ae86cab951a58fb70d4b74f69b3b0e7629c867875dfce19613f4e1f635963de-136
# Skipping record due to missing wallet_id or timestamp: 0x85a3346aeb6e14de5744eb6776a73cca0c89ff796b270df4b298ddb29c61e735-204
# Skipping record due to missing wallet_id or timestamp: 0xe74491903e94d1a650326e8bf1f2ff53592be9beca3f53e26af175e1754e8e20-142
# Skipping record due to missing wallet_id or timestamp: 0xada4bd0d23c581ea30332b272998db80873c12fc4754c7e046dc132bd12cb0ff-147
# Skipping record due to missing wallet_id or timestamp: 0xecf5a1f1b25ed9457fbfab89b4f6b742486d98e14d4221ce1df7bfc5399af779-136
# Skipping record due to missing wallet_id or timestamp: 0x7f4ee11c52247984d4c0ee35bfc4cfd408fa13d33c92237e3ce7d28afa7bc503-151
# Skipping record due to missing wallet_id or timestamp: 0x54371b0f3995ff63ad41c65bb8481439f3cc20d3783f25a25faeccb0d2514e44-192
# Skipping record due to missing wallet_id or timestamp: 0xd8841566ac275caab29bc0a6e6f19e624bd4e13acff08214676a514f120efbf8-252
# Skipping record due to missing wallet_id or timestamp: 0xefeb3b4f4bc660f072205ed37b041a1cf8f50441f11786a79b88f2c78a39f957-308
# Skipping record due to missing wallet_id or timestamp: 0xa9877c8180171749311455d4701e5cb170e50bc7c1a2d30a9526d6f64f5869a6-170
# Skipping record due to missing wallet_id or timestamp: 0x3416936118bab588308aaa6ad4c4e2e6d1158ff9bb706f38612855348814b247-371
# Skipping record due to missing wallet_id or timestamp: 0xde6741f5d56feb0303c87dafba96224832392269e8a582bad287decd2518f16a-331
# Skipping record due to missing wallet_id or timestamp: 0x190b566eedc20e9f67ef052cd9b469ed34ef2e62d0ff7d30c71cb8174bd1a347-147
# Skipping record due to missing wallet_id or timestamp: 0x8454c2cb8c93844683812f04ce158bb2940ffbe92fe3ba875b5c8fc1ce5d0dd0-183
# Skipping record due to missing wallet_id or timestamp: 0xc64ff3b17aad3460be9863f1f2f8af6ccfc80fc41db8d38eb473e833d8136cce-261
# Skipping record due to missing wallet_id or timestamp: 0x76daaf4c2628a4e1d9b40c1bee48b72b229a4d1d23e2f786f098ada4aad7784b-108
# Skipping record due to missing wallet_id or timestamp: 0x082d3b3ed395cb558637871f3d0d8fbf78c0c9d06e66c80c3e85fc8d8c22758d-351
# Skipping record due to missing wallet_id or timestamp: 0x85ea562d894e696ad9301929935bfc6e45239527c78286c154cc44f9f250d985-455
# Skipping record due to missing wallet_id or timestamp: 0x4e13d93bdab55eda00a92e281e0a74f523da13ffdafb8dcb6a82890a0772738b-236
# Skipping record due to missing wallet_id or timestamp: 0x820a7352dfcff529801d7d980b8fbf2608405de67528f3a257a90bd35674405c-182
# Skipping record due to missing wallet_id or timestamp: 0x2567309f0f85ee945945c1a00651c1a81619e69ee734a2fd2dd729b3d256173b-34
# Skipping record due to missing wallet_id or timestamp: 0xf5c5add44e859bfe58ffe0a18f9bbcf6773ebfaabff57567c704eccafe6dc632-77
# Skipping record due to missing wallet_id or timestamp: 0x229ea19e902d1a184aa64b5590b23fc00ce497de15ea3b557622e9772dbd276f-203
# Skipping record due to missing wallet_id or timestamp: 0xe9f59964e944c0646aed8d96dc70c570bb6fabfdc51a78481ae84f64fc37d093-276
# Skipping record due to missing wallet_id or timestamp: 0x8db964c0c3af8ff7dc418cb93e596552fa44f2d89474bbfdb93755a524f21bd5-420
# Skipping record due to missing wallet_id or timestamp: 0xda088a0030686deb09db7442ceb47b8693599758c2c5666eeba69ec9c4e2862b-219
# Skipping record due to missing wallet_id or timestamp: 0xe790d48b54623a9cadc4ae737c55118f499fd259929c993ec17bfedfd8d7f84b-274
# Skipping record due to missing wallet_id or timestamp: 0xc7a780ca9f5da41e530468f9211c6adf8c0042df728f89c1e3651c4da7758f0f-322
# Skipping record due to missing wallet_id or timestamp: 0xa4d559a06b2237df4c700881da81a49ec5ed57f22c06b0db5d4e13c2a7c787f5-410
# Skipping record due to missing wallet_id or timestamp: 0xfc427e60f4a8b502309d1407f852c663ca24a46d846eba3d000602f068459894-295
# Skipping record due to missing wallet_id or timestamp: 0xa03bb7e2bc292ace5f530eb9a8188cfd2fa23b6aa854ea66e8ed9e25c0b8248f-40
# Skipping record due to missing wallet_id or timestamp: 0xa3402791113ce95b5719180dbae9ba0b119bfd3551a2504d13591e8dffaf7331-635
# Skipping record due to missing wallet_id or timestamp: 0x4d918e45dd75fec78de9cc53c2992df2712c7c733d8e88ee7073083d4415e215-118
# Skipping record due to missing wallet_id or timestamp: 0x017cd0c0f5da5eae29ba61907766bbf951f834694efed9406d6016075f8b302d-286
# Skipping record due to missing wallet_id or timestamp: 0x5b52145ed58992b922039f448bb83bef1b1ac9325b1b18f5f57199370bcf60df-38
# Skipping record due to missing wallet_id or timestamp: 0xfee98ee7b9048d4564df41653d72ee454166f29b6e04b60a550f3401b15195df-53
# Skipping record due to missing wallet_id or timestamp: 0xd9be1d8f2c5e7822787ab5201287202432dd0578ae9d94ecb567f1da1c977d51-64
# Skipping record due to missing wallet_id or timestamp: 0x17e79e2e7d8b8fdfb7052a2188315d0779fefaaefd20940ced7d21c7b484d344-94
# Skipping record due to missing wallet_id or timestamp: 0x6873a6cec125e7be7b7c7e0cffbcb961b61e4198934c6cfc9ed1c89f048891ca-16
# Skipping record due to missing wallet_id or timestamp: 0x8d46e6586ebfa89a3416db8d5a4ab656a6eb1ccea24d06d6897a17e0c79b568b-142
# Skipping record due to missing wallet_id or timestamp: 0x8c02991ed4bea208d00d57faee9f1fa24dd9bbe3f26b9deb5438404b090e7cb7-101
# Skipping record due to missing wallet_id or timestamp: 0x1f3b2dafcb25b47905b461d30ccd5e9b1585c442726041b744169c97a9fe0922-224
# Skipping record due to missing wallet_id or timestamp: 0xa06e517945c88d59c00ab34eee9b4a4f581e46911ef2cb2da539e9d005ab1ce9-429
# Skipping record due to missing wallet_id or timestamp: 0xe8b627350f48d0e16aef5b380f7e80348d355ce473685402eb67e0a134ad368d-211
# Skipping record due to missing wallet_id or timestamp: 0xdbb1f10b7bcfa8d9da59ad1cc000b530994df4ca9d5b2a4b588af1ff7d3a4d51-131
# Skipping record due to missing wallet_id or timestamp: 0x99294af3ab1e213199dbbc0a78e027070347462dfd459935a1bbb199e45ea391-245
# Skipping record due to missing wallet_id or timestamp: 0xd7c9fa4763f5f6dba951a0f0a1c2c112fae8421eb8a1a9d28610dc0ab27e91d9-432
# Skipping record due to missing wallet_id or timestamp: 0x776797f1478eeb559d13a5d506c26c484fdc90208fe4a5b6a746d2ef5ed58725-18
# Skipping record due to missing wallet_id or timestamp: 0xb32e744ce8f7ce5d91759e713c28fbaf4012a5c416d9517ee8cb2713f09879db-409
# Skipping record due to missing wallet_id or timestamp: 0xa5bc399fcf3d68f87c78199c4eb94c0d298164b7bf63840c35f273ee2d520878-296
# Skipping record due to missing wallet_id or timestamp: 0xe72e21875f6b0e551a9f08dc220c345302b95631b01f55e7b8d1d171c74eb1d9-278
# Skipping record due to missing wallet_id or timestamp: 0x174f80e57db3ce9c20bd16f2c606b8cae312d4b5507be74223c45c67410edd9e-453
# Skipping record due to missing wallet_id or timestamp: 0x814faabea626b2104f883d45e694adbd0b0288180a334746a2da7b0c5498b3d7-329
# Skipping record due to missing wallet_id or timestamp: 0x1ead10cbd52d0aace6e8bf7fc56c7b897cbdcba8eb375d1ab89ddc7c404ed5fd-17
# Skipping record due to missing wallet_id or timestamp: 0xa482b6cf342ee3f6d5b6a0cd4175c22eee44242b930a2915dc0f1ac495d8a511-106
# Skipping record due to missing wallet_id or timestamp: 0x713e411ae1c8246169d4e6ca9f063d4a13e612d3538541c9905b05a75d0d4e05-418
# Skipping record due to missing wallet_id or timestamp: 0x799533a64af7bfe4d1427c74eece9e14368eb21921bef42e371ff7fed6f6f117-272
# Skipping record due to missing wallet_id or timestamp: 0x3bccf48309dab669c8911a25b59ea21f9160f9407137389a47a0409af18f3cee-326
# Skipping record due to missing wallet_id or timestamp: 0xe7bbb52f3a1cc25bb5ab93aea8e665941661fdf959954cb1e005f6d58fb3cc38-127
# Skipping record due to missing wallet_id or timestamp: 0xec1df9f5e42d992352bf4cdcfb7aef336fa988c07fe2cf211c38c89ef9081e89-81
# Skipping record due to missing wallet_id or timestamp: 0xf824150c9a33baf5e4cc11a80362c111f14880e85fe1cd6d538ec7ac3bdcb309-141
# Skipping record due to missing wallet_id or timestamp: 0x9109867b3554a247b91fce234a032a866fe3594c4a9b67c7acfd2902802c3451-19
# Skipping record due to missing wallet_id or timestamp: 0xb74114a8ecb5848fc6644ad68a9d684c31c7e6c45c335f9b40e418ac935cef8c-72
# Skipping record due to missing wallet_id or timestamp: 0xf22d01d70c226269f89f35b93d45dd8bae29e6f0007f7176c969ab0829db3b8e-174
# Skipping record due to missing wallet_id or timestamp: 0x402cc0fb228365231066307d52ac7a46b2e98300f8ea20f88fbfe61cdf2b66d2-121
# Skipping record due to missing wallet_id or timestamp: 0x4b2e7c9db1b1db66ce86dc96e347577e1a48f821935fec4ee838b42f0330f99c-17
# Skipping record due to missing wallet_id or timestamp: 0xb683f8dbcfdd274be442bf7db0affd6cb2d0ab5683e7388f4c36231481bfc165-107
# Skipping record due to missing wallet_id or timestamp: 0x02db2f1550f166313ca76f040141f60455cfd6cd8437e1e9f540c00afcbfe922-33
# Skipping record due to missing wallet_id or timestamp: 0x8cf44a624a7fe0566dbc23035fe9dea0441742cead113b6d62e352c69c5042ae-42
# Skipping record due to missing wallet_id or timestamp: 0xd6361320744d904c0cb098bb81d39f964865ee6e6449a703f0bc5a96976a2ab6-15
# Skipping record due to missing wallet_id or timestamp: 0xfb844aef4ff6959561d8895f87dcd75a6eafa5dd7b913f9a321475e59c841b3b-88
# Skipping record due to missing wallet_id or timestamp: 0x36c45111a4cf9914959a581dd3fc77d66efde8e1a21f4ad0a3b6822c9ca16923-89
# Skipping record due to missing wallet_id or timestamp: 0x7da549c2ced900c7e3370cf31f4cd5ba1d3dda1054ba25b582e0c6e62ceba603-55
# Skipping record due to missing wallet_id or timestamp: 0xe410c120ef0794c32f127280ec964d3f40171cc4d938467006133f1d38dbf5e0-315
# Skipping record due to missing wallet_id or timestamp: 0x62d9766077c8eb58d9839f2dd8f787aa741bda463e600d246ac26684bc328120-398
# Skipping record due to missing wallet_id or timestamp: 0xfa717e848cf5577f3b335d288e40e1ea29d21e7ab4c6c657a163884d7413b5e5-553
# Skipping record due to missing wallet_id or timestamp: 0xd3a44877e157a1ae2781c57557ae6d6fe49ccef4255a37c3345c4470b2f89c22-586
# Skipping record due to missing wallet_id or timestamp: 0x2f259dd6683af69c98cf85b6a079b3a72055a8679a8adfc46d7734bb3436682b-165
# Skipping record due to missing wallet_id or timestamp: 0x7113dc908bcb71f2ae835be7499cfb26c11d9529248c33c889c0f767e0a3b9b0-110
# Skipping record due to missing wallet_id or timestamp: 0x3ac997f6ec750d12bda586abf850ddf0ee74f2076509af3a5dc4ce3b7e16e746-402
# Skipping record due to missing wallet_id or timestamp: 0x3101927201acedde2f874072b3149ef623ea93ee6a899bcea0097016804da17a-177
# Skipping record due to missing wallet_id or timestamp: 0xf2dfa21339abb2a13a1ac585daadd2cdf7a830f33d60fde25574ccf82cfbcf61-300
# Skipping record due to missing wallet_id or timestamp: 0x026742d77e46dab7fb442c2af559ac8fa9e02c9709e5c188a265f2e2d981aebf-693
# Skipping record due to missing wallet_id or timestamp: 0x74451817d53aa7a9ed23a705d6b897c302d0f21884b0314ab9868cf21dadaa75-276
# Skipping record due to missing wallet_id or timestamp: 0x3420fdfdc6a0ee801b3d6fe099c0d94a2abb477c0140c6779560fa4e0f3aeea6-263
# Skipping record due to missing wallet_id or timestamp: 0xa06ba3517042ba33c75609b8b002098905a6e7bfd64ba160df9c1bea0addb72b-479
# Skipping record due to missing wallet_id or timestamp: 0x4e571895a01e958e279b0cba97fee8f5ff35d6e86c8916bbcc6f03341137635e-193
# Skipping record due to missing wallet_id or timestamp: 0xc2ff57dc530573fcdd391a79c458afbdb1da7b7b5e3d8d12da6eb32f6c476edc-308
# Skipping record due to missing wallet_id or timestamp: 0xe18d407bfd9a2a95a18d3d8a83eb527bf7c255c440559397f5a81455ce8689d7-186
# Skipping record due to missing wallet_id or timestamp: 0x0326a0dfc2a683d813a06c7fe4ea56473624cd1db9a21483b83891d685e661cc-389
# Skipping record due to missing wallet_id or timestamp: 0x69ce554abd91b3a1315e84ab063cd10f95c08ded1fdee41c0dd70df5d23911df-214
# Skipping record due to missing wallet_id or timestamp: 0x9e4b14ec35a0f3b91ddcee75ceb76e3c83d859b3b228f231575c07f13a4e2dff-116
# Skipping record due to missing wallet_id or timestamp: 0xe6aa3e73c32aa279fc9c505a8784c7cb47aad5b2e146fde81f9b73a3461cd368-1485
# Skipping record due to missing wallet_id or timestamp: 0xc2a9b3700ae9f4c5e98284d118cacbd8cef905308f608cf4406da6de49138ba2-414
# Skipping record due to missing wallet_id or timestamp: 0x47b4f3389b336aa31ff6320bccfaca7439316d2e3c687cf64f6d09458df0be99-224
# Skipping record due to missing wallet_id or timestamp: 0x93fde68af433f98c7fe36c9c9fafe9b3f485fc285561c07a9b8df1a4c45d957e-137
# Skipping record due to missing wallet_id or timestamp: 0x96600367a71c95ccaf9c6af39a1f7dcaf2235ff3463fb58f300029b0f9edde8d-370
# Skipping record due to missing wallet_id or timestamp: 0xd4449ed58d411721b8737501e806c2e7ce581e6f2f1f02cc7d5fe70b239ffcf5-94
# Processed 100000 total transactions.
# Sample processed data:
#                                              tx_hash  \
# 0  0xa1b27194b198762eaa631564fea76008b363c157a1cc...
# 1  0x1d2000c49507d94ef42ec995e1ea59b41e61bf0c63d4...
# 2  0x4c3b59d70f6205a16f4d6f4c960d22ad332dd740720a...
# 3  0xe8b31ff5cf7252a1a496dadfeccef667577d88cdf2c4...
# 4  0x0eda39d1cb1844e8c2f659219f5a414c0b8261e6dee5...
#
#                                               log_id           timestamp  \
# 0  0xa1b27194b198762eaa631564fea76008b363c157a1cc... 2019-05-07 01:41:22
# 1  0x1d2000c49507d94ef42ec995e1ea59b41e61bf0c63d4... 2019-05-07 01:45:11
# 2  0x4c3b59d70f6205a16f4d6f4c960d22ad332dd740720a... 2019-05-07 02:12:05
# 3  0xe8b31ff5cf7252a1a496dadfeccef667577d88cdf2c4... 2019-05-07 02:12:05
# 4  0x0eda39d1cb1844e8c2f659219f5a414c0b8261e6dee5... 2019-05-07 02:41:52
#
#   tx_type                                   wallet_id asset_symbol  \
# 0  depoit  0x502cb8985b2c92a8d4bf309cdaa89de9be442708          ETH
# 1  depoit  0xc8355d0e2c265b2fe495ebbc0fc9ad992b40dc8f          ETH
# 2  depoit  0x502cb8985b2c92a8d4bf309cdaa89de9be442708          BAT
# 3  depoit  0x502cb8985b2c92a8d4bf309cdaa89de9be442708          DAI
# 4  depoit  0x502cb8985b2c92a8d4bf309cdaa89de9be442708          ETH
#
#                                      asset_id        amount   amountUSD  \
# 0  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  1.000000e+16     1.78010
# 1  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  8.000000e+16    14.24080
# 2  0x0d8775f648430679a709e98d2b0cb6250d2887ef  4.582921e+21  1562.32014
# 3  0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359  4.013963e+21  4013.96294
# 4  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  9.990000e+18  1775.47275
#
#   liquidator liquidated_account
# 0       None               None
# 1       None               None
# 2       None               None
# 3       None               None
# 4       None               None
#
# Transaction Types Found:
# tx_type
# depoit      30000
# withdraw    30000
# borrow      20000
# repay       20000
# Name: count, dtype: int64
#
# Number of unique wallets: 22715

# %%
import numpy as np

# --- Feature Engineering ---
# Ensure data is sorted by time for sequential calculations if needed
df_tx = df_tx.sort_values(by=['wallet_id', 'timestamp'])

# Group by wallet
wallet_groups = df_tx.groupby('wallet_id')

features = {}

# --- Basic Aggregations ---
features['tx_count'] = wallet_groups.size()
features['unique_assets'] = wallet_groups['asset_symbol'].nunique()
features['first_tx_time'] = wallet_groups['timestamp'].min()
features['last_tx_time'] = wallet_groups['timestamp'].max()
features['account_lifespan_days'] = (features['last_tx_time'] - features['first_tx_time']).dt.total_seconds() / (60 * 60 * 24)

# %%
import numpy as np
import pandas as pd


# Calculate basic aggregations
features_agg = wallet_groups.agg(
    tx_count=('tx_hash', 'count'), # Use a non-null column like tx_hash
    unique_assets=('asset_symbol', 'nunique'),
    first_tx_time=('timestamp', 'min'),
    last_tx_time=('timestamp', 'max'),
    mean_tx_usd=('amountUSD', 'mean') # Calculate mean USD across all tx types here
)

# Calculate type-specific counts and sums using pivot_table or groupby().size().unstack()
tx_type_counts = df_tx.groupby(['wallet_id', 'tx_type']).size().unstack(fill_value=0)
tx_type_sums_usd = df_tx.groupby(['wallet_id', 'tx_type'])['amountUSD'].sum().unstack(fill_value=0)

# Rename columns for clarity (e.g., 'deposit' -> 'deposit_count', 'borrow' -> 'borrow_total_usd')
tx_type_counts.columns = [f"{col}_count" for col in tx_type_counts.columns]
tx_type_sums_usd.columns = [f"{col}_total_usd" for col in tx_type_sums_usd.columns]

# %%
# Combine aggregated features
df_features = pd.concat([features_agg, tx_type_counts, tx_type_sums_usd], axis=1)

# --- Fill NaNs for wallets that might be missing certain tx types ---
# Important: Ensure all expected columns exist, even if they are all zero
expected_tx_types = ['deposit', 'borrow', 'repay', 'withdraw', 'liquidation'] # Make sure these match your normalized types
for ttype in expected_tx_types:
    count_col = f"{ttype}_count"
    sum_col = f"{ttype}_total_usd"
    if count_col not in df_features.columns:
        df_features[count_col] = 0
    if sum_col not in df_features.columns:
        df_features[sum_col] = 0.0

# Fill any remaining NaNs (e.g., mean_tx_usd for wallets with 0 txns - though should be caught by groupby)
df_features.fillna(0, inplace=True)

# %%
# --- Calculate derived features AFTER ensuring columns exist ---

df_features['account_lifespan_days'] = (df_features['last_tx_time'] - df_features['first_tx_time']).dt.total_seconds() / (60 * 60 * 24)
# Ensure lifespan is at least a small number for frequency calculations
df_features['account_lifespan_days'] = df_features['account_lifespan_days'].apply(lambda x: max(x, 1/(24*60))) # Minimum 1 minute lifespan

# %%
# --- Liquidation Specific Features ---
# Times wallet WAS liquidated is now correctly calculated as 'liquidation_count' and 'liquidation_total_usd'

# Times wallet ACTED AS liquidator (Needs separate calculation as before)
liquidator_actions = df_tx[df_tx['tx_type'] == 'liquidation'].groupby('liquidator').agg(
    acted_liquidator_count=('tx_hash', 'count'),
    acted_liquidator_total_usd=('amountUSD', 'sum')
)
# Merge liquidator actions
df_features = df_features.merge(liquidator_actions, left_index=True, right_index=True, how='left')
# Fill NaNs for wallets that never acted as liquidators
df_features[['acted_liquidator_count', 'acted_liquidator_total_usd']] = df_features[['acted_liquidator_count', 'acted_liquidator_total_usd']].fillna(0)

# %%
# --- Derived Behavioral Features (Now Safe to Calculate Ratios) ---
epsilon = 1e-6 # To avoid division by zero

# Activity / Consistency (Using .apply here is okay as it's complex)
df_features['avg_time_between_tx_hours'] = wallet_groups['timestamp'].apply(
    lambda x: x.diff().mean().total_seconds() / 3600 if len(x) > 1 else 0
).fillna(0)

df_features['std_time_between_tx_hours'] = wallet_groups['timestamp'].apply(
    lambda x: x.diff().std().total_seconds() / 3600 if len(x) > 1 else 0
).fillna(0)

# Repayment Behavior Ratios
df_features['repay_borrow_count_ratio'] = df_features['repay_count'] / (df_features['borrow_count'] + epsilon)
df_features['repay_borrow_usd_ratio'] = df_features['repay_total_usd'] / (df_features['borrow_total_usd'] + epsilon)

# Deposit/Withdrawal Behavior
df_features['deposit_withdraw_usd_ratio'] = df_features['deposit_total_usd'] / (df_features['withdraw_total_usd'] + epsilon)
df_features['net_flow_usd'] = (df_features['deposit_total_usd'] + df_features['repay_total_usd']) - \
                              (df_features['borrow_total_usd'] + df_features['withdraw_total_usd'] + df_features['liquidation_total_usd'])

# %%
# Risk Indicators
# !! This is where the original error likely occurred !! Now it should work.
df_features['borrow_deposit_usd_ratio'] = df_features['borrow_total_usd'] / (df_features['deposit_total_usd'] + epsilon)
df_features['liquidated_ratio_count'] = df_features['liquidation_count'] / (df_features['tx_count'] + epsilon)
df_features['liquidated_ratio_usd'] = df_features['liquidation_total_usd'] / (df_features['borrow_total_usd'] + df_features['deposit_total_usd'] + epsilon)

# %%
# Bot-like Indicators (Heuristics)
df_features['tx_freq_per_day'] = df_features['tx_count'] / (df_features['account_lifespan_days'] + epsilon)
df_features['is_potentially_bot_time'] = ((df_features['std_time_between_tx_hours'] < 0.1) & (df_features['tx_count'] > 10)).astype(int) # Example threshold, store as 0/1
df_features['is_potentially_bot_dust'] = ((df_features['mean_tx_usd'] < 1.0) & (df_features['tx_count'] > 20)).astype(int) # Example threshold, store as 0/1


# --- Feature Cleaning/Refinement ---
df_features.replace([np.inf, -np.inf], 1e9, inplace=True) # Replace inf values

print("\nSample Features (Refactored):")
# Display relevant columns, including the ones that caused the error
print(df_features[['deposit_count', 'deposit_total_usd', 'borrow_count', 'borrow_total_usd', 'borrow_deposit_usd_ratio']].head())
print(f"\nTotal wallets with features: {len(df_features)}")
# Out:
# Sample Features (Refactored):
#                                             deposit_count  deposit_total_usd  \
# wallet_id
# 0x00000000000067afd7fa546d3f63d4e53cdb8fa4              0                0.0
# 0x0000000000007f150bd6f54c40a34d7c3d5e9f56              0                0.0
# 0x00000000af5a61acaf76190794e3fdf1289288a1              0                0.0
# 0x00000000fea1fab3ce021f3bedd21a94d0ba190c              0                0.0
# 0x000000aaee6a496aaf7b7452518781786313400f              0                0.0
#
#                                             borrow_count  borrow_total_usd  \
# wallet_id
# 0x00000000000067afd7fa546d3f63d4e53cdb8fa4             0      0.000000e+00
# 0x0000000000007f150bd6f54c40a34d7c3d5e9f56             0      0.000000e+00
# 0x00000000af5a61acaf76190794e3fdf1289288a1             0      0.000000e+00
# 0x00000000fea1fab3ce021f3bedd21a94d0ba190c             0      0.000000e+00
# 0x000000aaee6a496aaf7b7452518781786313400f           156      2.694435e+06
#
#                                             borrow_deposit_usd_ratio
# wallet_id
# 0x00000000000067afd7fa546d3f63d4e53cdb8fa4              0.000000e+00
# 0x0000000000007f150bd6f54c40a34d7c3d5e9f56              0.000000e+00
# 0x00000000af5a61acaf76190794e3fdf1289288a1              0.000000e+00
# 0x00000000fea1fab3ce021f3bedd21a94d0ba190c              0.000000e+00
# 0x000000aaee6a496aaf7b7452518781786313400f              2.694435e+12
#
# Total wallets with features: 22715

# %%
from sklearn.preprocessing import MinMaxScaler

# --- Scoring Logic ---

# 1. Define feature contributions (positive/negative impact) and weights
#    Weights are subjective and need tuning based on intuition and observation.
feature_weights = {
    # Positive Factors (+)
    'account_lifespan_days': 0.10,         # Longer is better
    'deposit_total_usd': 0.15,             # Higher value supplied is good (use log transform?)
    'repay_total_usd': 0.10,               # Higher repayment value is good (log transform?)
    'repay_borrow_usd_ratio': 0.10,        # Ratio > 1 is good, cap needed?
    'unique_assets': 0.05,                 # Diversity is mildly positive
    'acted_liquidator_count': 0.05,        # Contributing to protocol health
    'net_flow_usd': 0.05,                  # Positive net flow is good (use log transform?)

    # Negative Factors (-) - Weights are positive, but subtracted from score
    'liquidated_count': 0.20,              # Strongest negative signal
    'liquidated_ratio_usd': 0.10,          # High proportion of value lost to liquidation is bad
    'borrow_deposit_usd_ratio': 0.05,      # High leverage is risky (penalize high values)
    'tx_freq_per_day': 0.03,               # Very high frequency can be bot-like/negative (penalize extremes)
    'is_potentially_bot_time': 0.01,       # Minor penalty for bot-like timing
    'is_potentially_bot_dust': 0.01,       # Minor penalty for dust transactions
}

# %%
# Normalize features (0 to 1) before applying weights
# Use log transform for highly skewed $ amount features to reduce outlier impact
skewed_usd_features = ['deposit_total_usd', 'repay_total_usd', 'net_flow_usd', 'borrow_total_usd', 'withdraw_total_usd', 'liquidated_total_usd', 'acted_liquidator_total_usd']
for feat in skewed_usd_features:
    # Add 1 before log to handle zeros (log(1)=0)
    # Ensure column exists before transforming
    if feat in df_features.columns:
         # Handle potential negative values in net_flow_usd if needed before log
        if feat == 'net_flow_usd':
            # Option 1: Scale differently, e.g. using StandardScaler or custom logic
            # Option 2: Separate positive/negative net flow?
            # Let's use clipping and scaling for simplicity here
            df_features[f'{feat}_log_scaled'] = np.log1p(df_features[feat].clip(lower=0))
        else:
            df_features[f'{feat}_log_scaled'] = np.log1p(df_features[feat])

# %%
# Select features for scaling (include log-transformed versions)
features_to_scale = list(feature_weights.keys()) + [f'{f}_log_scaled' for f in skewed_usd_features if f'{f}_log_scaled' in df_features.columns]
# Remove original USD features if log version exists and is used in weights
features_to_scale = [f for f in features_to_scale if f not in skewed_usd_features or f'{f}_log_scaled' not in df_features.columns]
# Add boolean bot flags back if they were removed
if 'is_potentially_bot_time' not in features_to_scale: features_to_scale.append('is_potentially_bot_time')
if 'is_potentially_bot_dust' not in features_to_scale: features_to_scale.append('is_potentially_bot_dust')

# Ensure all features actually exist in the dataframe
features_to_scale = [f for f in features_to_scale if f in df_features.columns]
# Remove duplicates
features_to_scale = list(dict.fromkeys(features_to_scale))

# %%
scaler = MinMaxScaler()
# Scale only the selected features used in the score calculation
scaled_features = scaler.fit_transform(df_features[features_to_scale])
df_scaled_features = pd.DataFrame(scaled_features, index=df_features.index, columns=features_to_scale)


# 2. Calculate Raw Score
df_features['raw_score'] = 50.0 # Start with a neutral base score

# Apply weights - adjust feature names if log-transformed versions are used
# Example: use 'deposit_total_usd_log_scaled' instead of 'deposit_total_usd'
positive_impact_features = {
    'account_lifespan_days': feature_weights['account_lifespan_days'],
    'deposit_total_usd_log_scaled': feature_weights['deposit_total_usd'], # Use log scaled
    'repay_total_usd_log_scaled': feature_weights['repay_total_usd'],     # Use log scaled
    'repay_borrow_usd_ratio': feature_weights['repay_borrow_usd_ratio'], # Maybe cap this feature? df_scaled_features['repay_borrow_usd_ratio'].clip(upper=5)
    'unique_assets': feature_weights['unique_assets'],
    'acted_liquidator_count': feature_weights['acted_liquidator_count'], # Maybe log scale this too if skewed?
    'net_flow_usd_log_scaled': feature_weights['net_flow_usd'],          # Use log scaled version for positive flows
}

negative_impact_features = {
    'liquidated_count': feature_weights['liquidated_count'], # Higher value = lower score
    'liquidated_ratio_usd': feature_weights['liquidated_ratio_usd'], # Higher value = lower score
    'borrow_deposit_usd_ratio': feature_weights['borrow_deposit_usd_ratio'], # Higher value = lower score (maybe cap?)
    'tx_freq_per_day': feature_weights['tx_freq_per_day'], # Higher value = lower score
    'is_potentially_bot_time': feature_weights['is_potentially_bot_time'], # Boolean (0 or 1) * weight
    'is_potentially_bot_dust': feature_weights['is_potentially_bot_dust'], # Boolean (0 or 1) * weight
}

# %%
# Sum weighted contributions (using scaled features)
for feat, weight in positive_impact_features.items():
    if feat in df_scaled_features.columns:
        # Increase score, scale weight effect (e.g., multiply by 50 so max contribution is 50*weight)
        df_features['raw_score'] += df_scaled_features[feat] * weight * 50
    else:
        print(f"Warning: Positive feature {feat} not found in scaled features.")


for feat, weight in negative_impact_features.items():
    if feat in df_scaled_features.columns:
         # Decrease score, scale weight effect (e.g., multiply by 50 so max penalty is 50*weight)
        df_features['raw_score'] -= df_scaled_features[feat] * weight * 50
    else:
        print(f"Warning: Negative feature {feat} not found in scaled features.")


# 3. Scale final score to 0-100 range
final_scaler = MinMaxScaler(feature_range=(0, 100))
df_features['credit_score'] = final_scaler.fit_transform(df_features[['raw_score']])

# Optional: Inspect score distribution
print("\nScore Distribution:")
print(df_features['credit_score'].describe())

# Optional: Clip scores just in case scaling resulted in tiny values outside 0-100 due to float precision
df_features['credit_score'] = df_features['credit_score'].clip(0, 100)
# Out:
# Warning: Negative feature liquidated_count not found in scaled features.
#
# Score Distribution:
# count    22715.000000
# mean        12.618658
# std          6.726509
# min          0.000000
# 25%         10.053955
# 50%         10.053955
# 75%         11.513636
# max        100.000000
# Name: credit_score, dtype: float64

# %%
# Sort by score and select top 1000
top_1000_wallets = df_features.sort_values(by='credit_score', ascending=False).head(1000)

# Select only wallet_id and score for the final CSV
output_csv = top_1000_wallets[['credit_score']].reset_index()
output_csv.rename(columns={'index': 'wallet_id'}, inplace=True)

# Save to CSV
output_filename = 'top_1000_wallets.csv'
output_csv.to_csv(output_filename, index=False)
print(f"\nSaved top 1,000 wallets to {output_filename}")
# Out:
# Saved top 1,000 wallets to top_1000_wallets.csv

# %% [markdown]
# # Final Pipeline of the entire setup and analysis

# %%
# model_pipeline.py

import json
import pandas as pd
import numpy as np
from datetime import datetime
import os
import glob
from sklearn.preprocessing import MinMaxScaler
import warnings

# Suppress specific warnings if needed (e.g., for pandas apply)
# warnings.filterwarnings("ignore", category=DeprecationWarning)
# warnings.filterwarnings("ignore", category=FutureWarning)

print("--- Starting Compound V2 Wallet Scoring Pipeline ---")

# --- Configuration ---
# Assume data is in a 'data' subdirectory relative to the script
DATA_DIR = 'data/'
OUTPUT_DIR = 'outputs/'
# Create output dir if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Automatically find JSON files in the data directory
# In a real scenario, you'd implement logic to select the 3 largest files.
# For this example, let's assume we manually list them or just process all .json files found.
# json_files = glob.glob(os.path.join(DATA_DIR, '*.json'))
# Example: Manually list the 3 largest if needed after checking sizes
# files_to_process = [os.path.join(DATA_DIR, 'file1.json'), os.path.join(DATA_DIR, 'file2.json'), os.path.join(DATA_DIR, 'file3.json')]
# files_to_process = json_files # Process all found JSON files for this example
print(f"Found files to process: {files_to_process}")

if not files_to_process:
    print(f"Error: No JSON files found in {DATA_DIR}. Exiting.")
    exit()

# --- 1. Data Loading Function ---
def load_data(filepath):
    """Loads transaction data from a single JSON file."""
    try:
        with open(filepath, 'r') as f:
            # Handle potential multiple JSON objects per file if needed
            # For simplicity, assume one top-level object per file
            data = json.load(f)
        print(f"Successfully loaded {filepath}")
        return data
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from {filepath}: {e}")
        return None
    except Exception as e:
        print(f"Error loading {filepath}: {e}")
        return None

# --- 2. Data Processing Function ---
def process_raw_data(raw_data_list):
    """Processes raw data from multiple files into a single DataFrame."""
    all_tx = []
    # Define expected transaction types based on sample data
    valid_tx_keys = ['deposits', 'borrows', 'repayments', 'withdrawals', 'liquidations']

    for file_index, data in enumerate(raw_data_list):
        if data is None:
            print(f"Skipping empty or invalid data from file index {file_index}")
            continue

        # Check if data is a dictionary as expected
        if not isinstance(data, dict):
            print(f"Warning: Data from file index {file_index} is not a dictionary (found {type(data)}). Skipping.")
            continue

        for tx_key, transactions in data.items():
            # Check if the key is one we expect and if the value is a list
            if tx_key not in valid_tx_keys:
                print(f"Warning: Unexpected key '{tx_key}' in file index {file_index}. Skipping.")
                continue

            if not isinstance(transactions, list):
                print(f"Warning: Expected list for '{tx_key}', got {type(transactions)}. Skipping.")
                continue

            # Normalize key name
            normalized_tx_type = tx_key.lower().replace('s', '')
            if 'repayment' in normalized_tx_type: normalized_tx_type = 'repay'
            if 'withdrawal' in normalized_tx_type: normalized_tx_type = 'withdraw'

            for tx in transactions:
                try:
                    record = {
                        'tx_hash': tx.get('hash'),
                        'log_id': tx.get('id'),
                        'timestamp_unix': int(tx.get('timestamp')),
                        'tx_type': normalized_tx_type,
                        'wallet_id': tx.get('account', {}).get('id'),
                        'asset_symbol': tx.get('asset', {}).get('symbol'),
                        'asset_id': tx.get('asset', {}).get('id'),
                        'amount': float(tx.get('amount', 0)),
                        'amountUSD': float(tx.get('amountUSD', 0)),
                        'liquidator': None,
                        'liquidated_account': None
                    }

                    if normalized_tx_type == 'liquidation':
                        record['liquidator'] = tx.get('liquidator', {}).get('id')
                        record['liquidated_account'] = tx.get('account', {}).get('id')
                        # Override wallet_id to the account being liquidated for primary aggregation
                        record['wallet_id'] = record['liquidated_account']

                    # Basic validation
                    if record['wallet_id'] and record['timestamp_unix'] is not None and record['amountUSD'] >= 0:
                         # Convert timestamp here
                        record['timestamp'] = pd.to_datetime(record['timestamp_unix'], unit='s')
                        all_tx.append(record)
                    else:
                         print(f"Skipping record due to missing/invalid data: ID {tx.get('id', 'N/A')}")

                except (TypeError, ValueError) as e:
                    print(f"Error processing record {tx.get('id', 'N/A')} in {tx_key}: {e}. Skipping record.")
                except Exception as e:
                    print(f"Unexpected error processing record {tx.get('id', 'N/A')} in {tx_key}: {e}. Skipping record.")


    if not all_tx:
        print("Error: No valid transactions processed. Exiting.")
        exit()

    df = pd.DataFrame(all_tx)
    df = df.sort_values(by='timestamp').reset_index(drop=True)
    print(f"Processed {len(df)} total valid transactions.")
    return df

# --- 3. Feature Engineering Function ---
def engineer_features(df_tx):
    """Engineers features for each wallet."""
    print("Starting feature engineering...")
    if df_tx.empty:
        print("Cannot engineer features: Input DataFrame is empty.")
        return pd.DataFrame()

    # Group by wallet
    wallet_groups = df_tx.groupby('wallet_id')

    # Calculate basic aggregations
    features_agg = wallet_groups.agg(
        tx_count=('tx_hash', 'count'),
        unique_assets=('asset_symbol', 'nunique'),
        first_tx_time=('timestamp', 'min'),
        last_tx_time=('timestamp', 'max'),
        mean_tx_usd=('amountUSD', 'mean')
    )

    # Calculate type-specific counts and sums
    tx_type_counts = df_tx.groupby(['wallet_id', 'tx_type']).size().unstack(fill_value=0)
    tx_type_sums_usd = df_tx.groupby(['wallet_id', 'tx_type'])['amountUSD'].sum().unstack(fill_value=0)

    tx_type_counts.columns = [f"{col}_count" for col in tx_type_counts.columns]
    tx_type_sums_usd.columns = [f"{col}_total_usd" for col in tx_type_sums_usd.columns]

    # Combine aggregated features
    df_features = pd.concat([features_agg, tx_type_counts, tx_type_sums_usd], axis=1)

    # Ensure all expected columns exist, even if they are all zero
    expected_tx_types = ['deposit', 'borrow', 'repay', 'withdraw', 'liquidation']
    for ttype in expected_tx_types:
        count_col = f"{ttype}_count"
        sum_col = f"{ttype}_total_usd"
        if count_col not in df_features.columns: df_features[count_col] = 0
        if sum_col not in df_features.columns: df_features[sum_col] = 0.0

    df_features.fillna(0, inplace=True) # Fill any remaining NaNs

    # Calculate derived features
    df_features['account_lifespan_days'] = (df_features['last_tx_time'] - df_features['first_tx_time']).dt.total_seconds() / (60 * 60 * 24)
    df_features['account_lifespan_days'] = df_features['account_lifespan_days'].apply(lambda x: max(x, 1/(24*60))) # Min 1 min lifespan

    # Liquidation actor features
    liquidator_actions = df_tx[df_tx['tx_type'] == 'liquidation'].groupby('liquidator').agg(
        acted_liquidator_count=('tx_hash', 'count'),
        acted_liquidator_total_usd=('amountUSD', 'sum')
    ).rename_axis('wallet_id') # Rename index to merge correctly
    df_features = df_features.merge(liquidator_actions, left_index=True, right_index=True, how='left')
    df_features[['acted_liquidator_count', 'acted_liquidator_total_usd']] = df_features[['acted_liquidator_count', 'acted_liquidator_total_usd']].fillna(0)

    # Time-based features (using apply, may show warning)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=FutureWarning) # Suppress specific apply warning
        df_features['avg_time_between_tx_hours'] = wallet_groups['timestamp'].apply(
            lambda x: x.diff().mean().total_seconds() / 3600 if len(x) > 1 else 0
        ).fillna(0)
        df_features['std_time_between_tx_hours'] = wallet_groups['timestamp'].apply(
            lambda x: x.diff().std().total_seconds() / 3600 if len(x) > 1 else 0
        ).fillna(0)

    # Ratios and Indicators
    epsilon = 1e-6
    df_features['repay_borrow_count_ratio'] = df_features['repay_count'] / (df_features['borrow_count'] + epsilon)
    df_features['repay_borrow_usd_ratio'] = df_features['repay_total_usd'] / (df_features['borrow_total_usd'] + epsilon)
    df_features['deposit_withdraw_usd_ratio'] = df_features['deposit_total_usd'] / (df_features['withdraw_total_usd'] + epsilon)
    df_features['net_flow_usd'] = (df_features['deposit_total_usd'] + df_features['repay_total_usd']) - \
                                  (df_features['borrow_total_usd'] + df_features['withdraw_total_usd'] + df_features['liquidation_total_usd'])
    df_features['borrow_deposit_usd_ratio'] = df_features['borrow_total_usd'] / (df_features['deposit_total_usd'] + epsilon)
    df_features['liquidated_ratio_count'] = df_features['liquidation_count'] / (df_features['tx_count'] + epsilon)
    df_features['liquidated_ratio_usd'] = df_features['liquidation_total_usd'] / (df_features['borrow_total_usd'] + df_features['deposit_total_usd'] + epsilon)
    df_features['tx_freq_per_day'] = df_features['tx_count'] / (df_features['account_lifespan_days'] + epsilon)
    df_features['is_potentially_bot_time'] = ((df_features['std_time_between_tx_hours'] < 0.1) & (df_features['tx_count'] > 10)).astype(int)
    df_features['is_potentially_bot_dust'] = ((df_features['mean_tx_usd'] < 1.0) & (df_features['tx_count'] > 20)).astype(int)

    # Replace inf values just in case
    df_features.replace([np.inf, -np.inf], 1e12, inplace=True) # Use a large number instead of inf

    # Log transform skewed USD features (add column with _log suffix)
    skewed_usd_features = ['deposit_total_usd', 'repay_total_usd', 'borrow_total_usd', 'withdraw_total_usd', 'liquidation_total_usd', 'acted_liquidator_total_usd', 'net_flow_usd']
    for feat in skewed_usd_features:
        if feat in df_features.columns:
            if feat == 'net_flow_usd':
                # Handle potential negative values: scale shifted log
                min_net_flow = df_features[feat].min()
                df_features[f'{feat}_log'] = np.log1p(df_features[feat] - min_net_flow + epsilon) # Shift so min is >= 0
            else:
                 # Ensure non-negative before log1p
                df_features[f'{feat}_log'] = np.log1p(df_features[feat].clip(lower=0))
        else:
             print(f"Warning: Skewed feature {feat} not found for log transform.")


    print(f"Feature engineering complete. Generated {len(df_features.columns)} features for {len(df_features)} wallets.")
    return df_features

# --- 4. Scoring Function ---
def calculate_scores(df_features):
    """Calculates credit scores based on engineered features."""
    print("Calculating credit scores...")
    if df_features.empty:
        print("Cannot calculate scores: Input DataFrame is empty.")
        return df_features

    # Define feature contributions and weights (Adjust these based on domain knowledge/analysis)
    # Using log-transformed versions for amounts where available
    feature_weights = {
        # Positive Factors (+) - Higher value = Higher score contribution
        'account_lifespan_days': 0.08,
        'deposit_total_usd_log': 0.15,
        'repay_total_usd_log': 0.10,
        'repay_borrow_usd_ratio': 0.12, # Cap this later?
        'unique_assets': 0.03,
        'acted_liquidator_count': 0.05, # Maybe log transform count?
        'net_flow_usd_log': 0.05,
        'deposit_withdraw_usd_ratio': 0.02, # Mildly positive if > 1

        # Negative Factors (-) - Higher value = Lower score contribution (weights are positive magnitude)
        'liquidation_count': 0.20,       # Very important penalty
        'liquidated_ratio_usd': 0.10,    # High proportion liquidated is bad
        'borrow_deposit_usd_ratio': 0.06,# High leverage is risky
        'tx_freq_per_day': 0.02,         # Very high freq might be negative
        'is_potentially_bot_time': 0.01,
        'is_potentially_bot_dust': 0.01,
    }

    # Select features for scaling (make sure they exist in df_features)
    features_to_scale = [f for f in feature_weights.keys() if f in df_features.columns]

    # Cap extreme ratio features before scaling to prevent excessive influence
    if 'repay_borrow_usd_ratio' in df_features.columns:
        df_features['repay_borrow_usd_ratio_capped'] = df_features['repay_borrow_usd_ratio'].clip(upper=10) # Example cap
        if 'repay_borrow_usd_ratio_capped' not in features_to_scale: features_to_scale.append('repay_borrow_usd_ratio_capped')
        if 'repay_borrow_usd_ratio' in features_to_scale: features_to_scale.remove('repay_borrow_usd_ratio') # Use capped version

    if 'borrow_deposit_usd_ratio' in df_features.columns:
        df_features['borrow_deposit_usd_ratio_capped'] = df_features['borrow_deposit_usd_ratio'].clip(upper=20) # Example cap (20x leverage is huge)
        if 'borrow_deposit_usd_ratio_capped' not in features_to_scale: features_to_scale.append('borrow_deposit_usd_ratio_capped')
        if 'borrow_deposit_usd_ratio' in features_to_scale: features_to_scale.remove('borrow_deposit_usd_ratio') # Use capped version

    if 'deposit_withdraw_usd_ratio' in df_features.columns:
        df_features['deposit_withdraw_usd_ratio_capped'] = df_features['deposit_withdraw_usd_ratio'].clip(upper=10) # Example cap
        if 'deposit_withdraw_usd_ratio_capped' not in features_to_scale: features_to_scale.append('deposit_withdraw_usd_ratio_capped')
        if 'deposit_withdraw_usd_ratio' in features_to_scale: features_to_scale.remove('deposit_withdraw_usd_ratio') # Use capped version

    if 'tx_freq_per_day' in df_features.columns:
        df_features['tx_freq_per_day_capped'] = df_features['tx_freq_per_day'].clip(upper=df_features['tx_freq_per_day'].quantile(0.99)) # Cap at 99th percentile
        if 'tx_freq_per_day_capped' not in features_to_scale: features_to_scale.append('tx_freq_per_day_capped')
        if 'tx_freq_per_day' in features_to_scale: features_to_scale.remove('tx_freq_per_day') # Use capped version


    # Scale only the selected (and potentially capped) features
    scaler = MinMaxScaler()
    scaled_features_data = scaler.fit_transform(df_features[features_to_scale])
    df_scaled_features = pd.DataFrame(scaled_features_data, index=df_features.index, columns=features_to_scale)

    # Calculate Raw Score
    df_features['raw_score'] = 50.0 # Start neutral

    positive_features = [
        'account_lifespan_days', 'deposit_total_usd_log', 'repay_total_usd_log',
        'repay_borrow_usd_ratio_capped', 'unique_assets', 'acted_liquidator_count',
        'net_flow_usd_log', 'deposit_withdraw_usd_ratio_capped'
    ]
    negative_features = [
        'liquidation_count', 'liquidated_ratio_usd', 'borrow_deposit_usd_ratio_capped',
        'tx_freq_per_day_capped', 'is_potentially_bot_time', 'is_potentially_bot_dust'
    ]

    # Sum weighted contributions (using scaled features)
    total_weight_applied = 0
    for feat, weight in feature_weights.items():
        # Determine the actual feature name used (original or capped/log version)
        scaled_feat_name = feat
        if feat + '_capped' in df_scaled_features.columns:
            scaled_feat_name = feat + '_capped'
        elif feat + '_log' in df_scaled_features.columns:
             scaled_feat_name = feat + '_log'

        if scaled_feat_name in df_scaled_features.columns:
            if feat in positive_features:
                df_features['raw_score'] += df_scaled_features[scaled_feat_name] * weight * 50 # Max contribution = weight * 50
            elif feat in negative_features:
                df_features['raw_score'] -= df_scaled_features[scaled_feat_name] * weight * 50 # Max penalty = weight * 50
            total_weight_applied += weight
        else:
            print(f"Warning: Feature '{feat}' (or derived version) not found in scaled features for scoring.")

    print(f"Applied scoring logic using {len(features_to_scale)} features with total weight magnitude: {total_weight_applied:.2f}")

    # Scale final score to 0-100 range
    final_scaler = MinMaxScaler(feature_range=(0, 100))
    df_features['credit_score'] = final_scaler.fit_transform(df_features[['raw_score']])
    df_features['credit_score'] = df_features['credit_score'].round(2) # Round for cleaner output

    print("Credit scoring complete.")
    return df_features


# --- Main Execution ---
# 1. Load Data
print("--- Phase 1: Loading Data ---")
raw_data_loaded = [load_data(f_path) for f_path in files_to_process]
raw_data_loaded = [d for d in raw_data_loaded if d is not None] # Filter out failed loads

if not raw_data_loaded:
    print("Error: No data could be loaded. Exiting.")
    exit()

# 2. Process Data
print("\n--- Phase 2: Processing Raw Data ---")
df_tx = process_raw_data(raw_data_loaded)

# 3. Engineer Features
print("\n--- Phase 3: Engineering Features ---")
df_features = engineer_features(df_tx)

# 4. Calculate Scores
print("\n--- Phase 4: Calculating Scores ---")
df_scored_features = calculate_scores(df_features)

# --- 5. Output Generation ---
print("\n--- Phase 5: Generating Outputs ---")

# Save the full features and scores DataFrame (useful for Streamlit app and analysis)
full_output_path = os.path.join(OUTPUT_DIR, 'wallet_scores_features.csv')
try:
    df_scored_features.reset_index().to_csv(full_output_path, index=False)
    print(f"Successfully saved full features and scores to {full_output_path}")
except Exception as e:
    print(f"Error saving full features CSV: {e}")

# Save the Top 1,000 Wallets CSV
top_1000_output_path = os.path.join(OUTPUT_DIR, 'top_1000_wallets.csv')
try:
    top_1000_wallets = df_scored_features.sort_values(by='credit_score', ascending=False).head(1000)
    # Select only wallet_id and score
    top_1000_output_csv = top_1000_wallets[['credit_score']].reset_index()
    # top_1000_output_csv.rename(columns={'index': 'wallet_id'}, inplace=True) # Index name is already 'wallet_id'
    top_1000_output_csv.to_csv(top_1000_output_path, index=False)
    print(f"Successfully saved top 1,000 wallets to {top_1000_output_path}")
except Exception as e:
    print(f"Error saving top 1000 wallets CSV: {e}")


# --- Generate Wallet Analysis Snippets (for the separate document) ---
print("\n--- Generating Wallet Analysis Snippets ---")
analysis_output_path = os.path.join(OUTPUT_DIR, 'wallet_analysis_snippets.txt')
try:
    with open(analysis_output_path, 'w') as f:
        f.write("Wallet Analysis (Top 5 High / Top 5 Low Scores)\n")
        f.write("="*50 + "\n\n")

        top_5 = df_scored_features.sort_values(by='credit_score', ascending=False).head(5)
        low_5 = df_scored_features.sort_values(by='credit_score', ascending=True).head(5)

        f.write("--- Top 5 High-Scoring Wallets ---\n")
        for wallet_id, data in top_5.iterrows():
            f.write(f"\nWallet ID: {wallet_id}\n")
            f.write(f"Score: {data['credit_score']:.2f}\n")
            f.write(f"Key Features:\n")
            f.write(f"  - Lifespan (Days): {data.get('account_lifespan_days', 'N/A'):.1f}\n")
            f.write(f"  - Deposit USD (Log): {data.get('deposit_total_usd_log', 'N/A'):.2f}\n")
            f.write(f"  - Repay/Borrow USD Ratio: {data.get('repay_borrow_usd_ratio', 'N/A'):.2f} (Capped: {data.get('repay_borrow_usd_ratio_capped', 'N/A'):.2f})\n")
            f.write(f"  - Liquidated Count: {int(data.get('liquidation_count', 0))}\n")
            f.write(f"  - Acted Liquidator Count: {int(data.get('acted_liquidator_count', 0))}\n")
            f.write(f"  - Borrow/Deposit USD Ratio: {data.get('borrow_deposit_usd_ratio', 'N/A'):.2f} (Capped: {data.get('borrow_deposit_usd_ratio_capped', 'N/A'):.2f})\n")
            # Add more features as needed
            f.write("Justification: High score likely due to significant deposits/repayments, long lifespan, potentially acting as liquidator, and absence of liquidations.\n")


        f.write("\n--- Top 5 Low-Scoring Wallets ---\n")
        for wallet_id, data in low_5.iterrows():
            f.write(f"\nWallet ID: {wallet_id}\n")
            f.write(f"Score: {data['credit_score']:.2f}\n")
            f.write(f"Key Features:\n")
            f.write(f"  - Lifespan (Days): {data.get('account_lifespan_days', 'N/A'):.1f}\n")
            f.write(f"  - Deposit USD (Log): {data.get('deposit_total_usd_log', 'N/A'):.2f}\n")
            f.write(f"  - Repay/Borrow USD Ratio: {data.get('repay_borrow_usd_ratio', 'N/A'):.2f} (Capped: {data.get('repay_borrow_usd_ratio_capped', 'N/A'):.2f})\n")
            f.write(f"  - Liquidated Count: {int(data.get('liquidation_count', 0))}\n")
            f.write(f"  - Liquidated Ratio USD: {data.get('liquidated_ratio_usd', 'N/A'):.4f}\n")
            f.write(f"  - Acted Liquidator Count: {int(data.get('acted_liquidator_count', 0))}\n")
            f.write(f"  - Borrow/Deposit USD Ratio: {data.get('borrow_deposit_usd_ratio', 'N/A'):.2f} (Capped: {data.get('borrow_deposit_usd_ratio_capped', 'N/A'):.2f})\n")
            # Add more features as needed
            f.write("Justification: Low score likely driven by liquidations (high count or high ratio), high leverage (borrow/deposit ratio), or potentially short lifespan/low activity.\n")

    print(f"Successfully generated wallet analysis snippets to {analysis_output_path}")
except Exception as e:
    print(f"Error generating wallet analysis snippets: {e}")


print("\n--- Pipeline Finished ---")
# Out:
# --- Starting Compound V2 Wallet Scoring Pipeline ---
# Found files to process: ['/content/compoundV2_transactions_ethereum_chunk_0.json', '/content/compoundV2_transactions_ethereum_chunk_1.json', '/content/compoundV2_transactions_ethereum_chunk_32.json']
# --- Phase 1: Loading Data ---
# Successfully loaded /content/compoundV2_transactions_ethereum_chunk_0.json
# Successfully loaded /content/compoundV2_transactions_ethereum_chunk_1.json
# Successfully loaded /content/compoundV2_transactions_ethereum_chunk_32.json
#
# --- Phase 2: Processing Raw Data ---
# Warning: Unexpected key 'withdraws' in file index 0. Skipping.
# Warning: Unexpected key 'repays' in file index 0. Skipping.
# Warning: Unexpected key 'liquidates' in file index 0. Skipping.
# Warning: Unexpected key 'withdraws' in file index 1. Skipping.
# Warning: Unexpected key 'repays' in file index 1. Skipping.
# Warning: Unexpected key 'liquidates' in file index 1. Skipping.
# Warning: Unexpected key 'withdraws' in file index 2. Skipping.
# Warning: Unexpected key 'repays' in file index 2. Skipping.
# Warning: Unexpected key 'liquidates' in file index 2. Skipping.
# Processed 50000 total valid transactions.
#
# --- Phase 3: Engineering Features ---
# Starting feature engineering...
# Feature engineering complete. Generated 39 features for 16274 wallets.
#
# --- Phase 4: Calculating Scores ---
# Calculating credit scores...
# Applied scoring logic using 14 features with total weight magnitude: 1.00
# Credit scoring complete.
#
# --- Phase 5: Generating Outputs ---
# Successfully saved full features and scores to outputs/wallet_scores_features.csv
# Successfully saved top 1,000 wallets to outputs/top_1000_wallets.csv
#
# --- Generating Wallet Analysis Snippets ---
# Successfully generated wallet analysis snippets to outputs/wallet_analysis_snippets.txt
#
# --- Pipeline Finished ---
